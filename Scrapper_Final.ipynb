# %% [markdown]
# <a href="https://colab.research.google.com/github/rajeev-dw9/Scrapper_DSIP/blob/main/Scrapper_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Web Scrapping Assignment
# Name: Rajeev Ranjan Dwivedi
# Date: 26/10/2022
# Description: This program scrapes the data from the website (https://ascopubs.org/loi/jco) and stores it in a csv file.

# %%
# reset all variable, since it creates problem while running the code again and again
# %reset -f

# %%
# import libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd 
import csv


import time
import re
import os
import sys
import json
import datetime

# %%
# Get the data from the website
response = requests.get("https://ascopubs.org/loi/jco") # get the data from the website
soup = BeautifulSoup(response.text, "html.parser") # parse the data using beautiful soup

list_of_links = [] # list of links
all_links = soup.find_all("a") # find all links
for link in all_links:
    list_of_links.append(link.get("href")) # append the link to the list
    
# print(list_of_links)

# %%
# Store all the links in a dataframe
df = pd.DataFrame(list_of_links, columns = ["Links"])
df.head(100)
# Out:
#                                                 Links
# 0                                               #main
# 1                                        /journal/jco
# 2   https://signin.asco.org/oauth2/aus1goap5nQ33vo...
# 3   http://www.editorialmanager.com/jco-ascopubs/d...
# 4   https://apps.asco.org/EmailPreferences/Home/Up...
# ..                                                ...
# 95                                      /toc/jco/40/7
# 96                                      /toc/jco/40/6
# 97                                      /toc/jco/40/5
# 98                                      /toc/jco/40/4
# 99                                      /toc/jco/40/3
#
# [100 rows x 1 columns]

# %%
# remove columns with null values
df = df.dropna()
df.head(100)

# remove the links that are not related to the journal articles
df = df[df["Links"].str.contains("/toc/jco")]
df.shape
# Out:
# (967, 1)

# %%
from tqdm import tqdm

url = "https://ascopubs.org/toc/jco/"

data = []

for i in tqdm(range(1, 41)):
    out_url = url + str(i)
    index = 1
    
    year_data = []
    
    while True:
        titles = []
        authors = []
        articles = []
        
        target_url = out_url + "/" + str(index)
        
        response = requests.get(target_url) # get the data from the website
        if response.status_code == 404:
            break
        soup = BeautifulSoup(response.text, "html.parser")
        print(index, target_url, end=" ")
        
        tables = soup.find_all("table", {"class": "articleEntry"})
        for table in tables:
            # getting title
            title = table.find_all("span", {"class":"hlFld-Title"})
            if(len(title) > 0):
                titles.append(title[0].text)
            else:
                titles.append("")
                
            # getting author
            author = table.find_all("span", {"class":"entryAuthor"})
            if (len(author) > 0):
                authors.append(author[0].text)
            else:
                authors.append("")

            # getting pdf url
            pdf_url = table.find_all("a", {"class":"pdf"})[0].get('href')
            if not pdf_url.startswith('https://ascopubs.org/'):
                pdf_url = 'https://ascopubs.org' + pdf_url
            articles.append(pdf_url)
        year_data.append([titles, authors, articles])
        index += 1
        
    data.append(year_data)
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
# 1 https://ascopubs.org/toc/jco/1/1 2 https://ascopubs.org/toc/jco/1/2 3 https://ascopubs.org/toc/jco/1/3 4 https://ascopubs.org/toc/jco/1/4 5 https://ascopubs.org/toc/jco/1/5 6 https://ascopubs.org/toc/jco/1/6 7 https://ascopubs.org/toc/jco/1/7 8 https://ascopubs.org/toc/jco/1/8 9 https://ascopubs.org/toc/jco/1/9 10 https://ascopubs.org/toc/jco/1/10 11 https://ascopubs.org/toc/jco/1/11 12 https://ascopubs.org/toc/jco/1/12
#   2%|▎         | 1/40 [00:13<09:02, 13.91s/it]
# 1 https://ascopubs.org/toc/jco/2/1 2 https://ascopubs.org/toc/jco/2/2 3 https://ascopubs.org/toc/jco/2/3 4 https://ascopubs.org/toc/jco/2/4 5 https://ascopubs.org/toc/jco/2/5 6 https://ascopubs.org/toc/jco/2/6 7 https://ascopubs.org/toc/jco/2/7 8 https://ascopubs.org/toc/jco/2/8 9 https://ascopubs.org/toc/jco/2/9 10 https://ascopubs.org/toc/jco/2/10 11 https://ascopubs.org/toc/jco/2/11 12 https://ascopubs.org/toc/jco/2/12
#   5%|▌         | 2/40 [00:32<10:35, 16.73s/it]
# 1 https://ascopubs.org/toc/jco/3/1 2 https://ascopubs.org/toc/jco/3/2 3 https://ascopubs.org/toc/jco/3/3 4 https://ascopubs.org/toc/jco/3/4 5 https://ascopubs.org/toc/jco/3/5 6 https://ascopubs.org/toc/jco/3/6 7 https://ascopubs.org/toc/jco/3/7 8 https://ascopubs.org/toc/jco/3/8 9 https://ascopubs.org/toc/jco/3/9 10 https://ascopubs.org/toc/jco/3/10 11 https://ascopubs.org/toc/jco/3/11 12 https://ascopubs.org/toc/jco/3/12
#   8%|▊         | 3/40 [00:50<10:37, 17.24s/it]
# 1 https://ascopubs.org/toc/jco/4/1 2 https://ascopubs.org/toc/jco/4/2 3 https://ascopubs.org/toc/jco/4/3 4 https://ascopubs.org/toc/jco/4/4 5 https://ascopubs.org/toc/jco/4/5 6 https://ascopubs.org/toc/jco/4/6 7 https://ascopubs.org/toc/jco/4/7 8 https://ascopubs.org/toc/jco/4/8 9 https://ascopubs.org/toc/jco/4/9 10 https://ascopubs.org/toc/jco/4/10 11 https://ascopubs.org/toc/jco/4/11 12 https://ascopubs.org/toc/jco/4/12
#  10%|█         | 4/40 [01:11<11:12, 18.67s/it]
# 1 https://ascopubs.org/toc/jco/5/1 2 https://ascopubs.org/toc/jco/5/2 3 https://ascopubs.org/toc/jco/5/3 4 https://ascopubs.org/toc/jco/5/4 5 https://ascopubs.org/toc/jco/5/5 6 https://ascopubs.org/toc/jco/5/6 7 https://ascopubs.org/toc/jco/5/7 8 https://ascopubs.org/toc/jco/5/8 9 https://ascopubs.org/toc/jco/5/9 10 https://ascopubs.org/toc/jco/5/10 11 https://ascopubs.org/toc/jco/5/11 12 https://ascopubs.org/toc/jco/5/12
#  12%|█▎        | 5/40 [01:32<11:30, 19.73s/it]
# 1 https://ascopubs.org/toc/jco/6/1 2 https://ascopubs.org/toc/jco/6/2 3 https://ascopubs.org/toc/jco/6/3 4 https://ascopubs.org/toc/jco/6/4 5 https://ascopubs.org/toc/jco/6/5 6 https://ascopubs.org/toc/jco/6/6 7 https://ascopubs.org/toc/jco/6/7 8 https://ascopubs.org/toc/jco/6/8 9 https://ascopubs.org/toc/jco/6/9 10 https://ascopubs.org/toc/jco/6/10 11 https://ascopubs.org/toc/jco/6/11 12 https://ascopubs.org/toc/jco/6/12
#  15%|█▌        | 6/40 [01:51<10:59, 19.39s/it]
# 1 https://ascopubs.org/toc/jco/7/1 2 https://ascopubs.org/toc/jco/7/2 3 https://ascopubs.org/toc/jco/7/3 4 https://ascopubs.org/toc/jco/7/4 5 https://ascopubs.org/toc/jco/7/5 6 https://ascopubs.org/toc/jco/7/6 7 https://ascopubs.org/toc/jco/7/7 8 https://ascopubs.org/toc/jco/7/8 9 https://ascopubs.org/toc/jco/7/9 10 https://ascopubs.org/toc/jco/7/10 11 https://ascopubs.org/toc/jco/7/11 12 https://ascopubs.org/toc/jco/7/12
#  18%|█▊        | 7/40 [02:11<10:47, 19.62s/it]
# 1 https://ascopubs.org/toc/jco/8/1 2 https://ascopubs.org/toc/jco/8/2 3 https://ascopubs.org/toc/jco/8/3 4 https://ascopubs.org/toc/jco/8/4 5 https://ascopubs.org/toc/jco/8/5 6 https://ascopubs.org/toc/jco/8/6 7 https://ascopubs.org/toc/jco/8/7 8 https://ascopubs.org/toc/jco/8/8 9 https://ascopubs.org/toc/jco/8/9 10 https://ascopubs.org/toc/jco/8/10 11 https://ascopubs.org/toc/jco/8/11 12 https://ascopubs.org/toc/jco/8/12
#  20%|██        | 8/40 [02:35<11:08, 20.89s/it]
# 1 https://ascopubs.org/toc/jco/9/1 2 https://ascopubs.org/toc/jco/9/2 3 https://ascopubs.org/toc/jco/9/3 4 https://ascopubs.org/toc/jco/9/4 5 https://ascopubs.org/toc/jco/9/5 6 https://ascopubs.org/toc/jco/9/6 7 https://ascopubs.org/toc/jco/9/7 8 https://ascopubs.org/toc/jco/9/8 9 https://ascopubs.org/toc/jco/9/9 10 https://ascopubs.org/toc/jco/9/10 11 https://ascopubs.org/toc/jco/9/11 12 https://ascopubs.org/toc/jco/9/12
#  22%|██▎       | 9/40 [02:58<11:07, 21.53s/it]
# 1 https://ascopubs.org/toc/jco/10/1 2 https://ascopubs.org/toc/jco/10/2 3 https://ascopubs.org/toc/jco/10/3 4 https://ascopubs.org/toc/jco/10/4 5 https://ascopubs.org/toc/jco/10/5 6 https://ascopubs.org/toc/jco/10/6 7 https://ascopubs.org/toc/jco/10/7 8 https://ascopubs.org/toc/jco/10/8 9 https://ascopubs.org/toc/jco/10/9 10 https://ascopubs.org/toc/jco/10/10 11 https://ascopubs.org/toc/jco/10/11 12 https://ascopubs.org/toc/jco/10/12
#  25%|██▌       | 10/40 [03:20<10:47, 21.59s/it]
# 1 https://ascopubs.org/toc/jco/11/1 2 https://ascopubs.org/toc/jco/11/2 3 https://ascopubs.org/toc/jco/11/3 4 https://ascopubs.org/toc/jco/11/4 5 https://ascopubs.org/toc/jco/11/5 6 https://ascopubs.org/toc/jco/11/6 7 https://ascopubs.org/toc/jco/11/7 8 https://ascopubs.org/toc/jco/11/8 9 https://ascopubs.org/toc/jco/11/9 10 https://ascopubs.org/toc/jco/11/10 11 https://ascopubs.org/toc/jco/11/11 12 https://ascopubs.org/toc/jco/11/12
#  28%|██▊       | 11/40 [03:46<11:08, 23.05s/it]
# 1 https://ascopubs.org/toc/jco/12/1 2 https://ascopubs.org/toc/jco/12/2 3 https://ascopubs.org/toc/jco/12/3 4 https://ascopubs.org/toc/jco/12/4 5 https://ascopubs.org/toc/jco/12/5 6 https://ascopubs.org/toc/jco/12/6 7 https://ascopubs.org/toc/jco/12/7 8 https://ascopubs.org/toc/jco/12/8 9 https://ascopubs.org/toc/jco/12/9 10 https://ascopubs.org/toc/jco/12/10 11 https://ascopubs.org/toc/jco/12/11 12 https://ascopubs.org/toc/jco/12/12
#  30%|███       | 12/40 [04:12<11:09, 23.92s/it]
# 1 https://ascopubs.org/toc/jco/13/1 2 https://ascopubs.org/toc/jco/13/2 3 https://ascopubs.org/toc/jco/13/3 4 https://ascopubs.org/toc/jco/13/4 5 https://ascopubs.org/toc/jco/13/5 6 https://ascopubs.org/toc/jco/13/6 7 https://ascopubs.org/toc/jco/13/7 8 https://ascopubs.org/toc/jco/13/8 9 https://ascopubs.org/toc/jco/13/9 10 https://ascopubs.org/toc/jco/13/10 11 https://ascopubs.org/toc/jco/13/11 12 https://ascopubs.org/toc/jco/13/12
#  32%|███▎      | 13/40 [04:40<11:20, 25.19s/it]
# 1 https://ascopubs.org/toc/jco/14/1 2 https://ascopubs.org/toc/jco/14/2 3 https://ascopubs.org/toc/jco/14/3 4 https://ascopubs.org/toc/jco/14/4 5 https://ascopubs.org/toc/jco/14/5 6 https://ascopubs.org/toc/jco/14/6 7 https://ascopubs.org/toc/jco/14/7 8 https://ascopubs.org/toc/jco/14/8 9 https://ascopubs.org/toc/jco/14/9 10 https://ascopubs.org/toc/jco/14/10 11 https://ascopubs.org/toc/jco/14/11 12 https://ascopubs.org/toc/jco/14/12
#  35%|███▌      | 14/40 [05:09<11:27, 26.45s/it]
# 1 https://ascopubs.org/toc/jco/15/1 2 https://ascopubs.org/toc/jco/15/2 3 https://ascopubs.org/toc/jco/15/3 4 https://ascopubs.org/toc/jco/15/4 5 https://ascopubs.org/toc/jco/15/5 6 https://ascopubs.org/toc/jco/15/6 7 https://ascopubs.org/toc/jco/15/7 8 https://ascopubs.org/toc/jco/15/8 9 https://ascopubs.org/toc/jco/15/9 10 https://ascopubs.org/toc/jco/15/10 11 https://ascopubs.org/toc/jco/15/11 12 https://ascopubs.org/toc/jco/15/12
#  38%|███▊      | 15/40 [05:39<11:25, 27.42s/it]
# 1 https://ascopubs.org/toc/jco/16/1 2 https://ascopubs.org/toc/jco/16/2 3 https://ascopubs.org/toc/jco/16/3 4 https://ascopubs.org/toc/jco/16/4 5 https://ascopubs.org/toc/jco/16/5 6 https://ascopubs.org/toc/jco/16/6 7 https://ascopubs.org/toc/jco/16/7 8 https://ascopubs.org/toc/jco/16/8 9 https://ascopubs.org/toc/jco/16/9 10 https://ascopubs.org/toc/jco/16/10 11 https://ascopubs.org/toc/jco/16/11 12 https://ascopubs.org/toc/jco/16/12
#  40%|████      | 16/40 [06:14<11:55, 29.80s/it]
# 1 https://ascopubs.org/toc/jco/17/1 2 https://ascopubs.org/toc/jco/17/2 3 https://ascopubs.org/toc/jco/17/3 4 https://ascopubs.org/toc/jco/17/4 5 https://ascopubs.org/toc/jco/17/5 6 https://ascopubs.org/toc/jco/17/6 7 https://ascopubs.org/toc/jco/17/7 8 https://ascopubs.org/toc/jco/17/8 9 https://ascopubs.org/toc/jco/17/9 10 https://ascopubs.org/toc/jco/17/10 11 https://ascopubs.org/toc/jco/17/11 12 https://ascopubs.org/toc/jco/17/12
#  42%|████▎     | 17/40 [06:46<11:40, 30.47s/it]
# 1 https://ascopubs.org/toc/jco/18/1 2 https://ascopubs.org/toc/jco/18/2 3 https://ascopubs.org/toc/jco/18/3 4 https://ascopubs.org/toc/jco/18/4 5 https://ascopubs.org/toc/jco/18/5 6 https://ascopubs.org/toc/jco/18/6 7 https://ascopubs.org/toc/jco/18/7 8 https://ascopubs.org/toc/jco/18/8 9 https://ascopubs.org/toc/jco/18/9 10 https://ascopubs.org/toc/jco/18/10 11 https://ascopubs.org/toc/jco/18/11 12 https://ascopubs.org/toc/jco/18/12 13 https://ascopubs.org/toc/jco/18/13 14 https://ascopubs.org/toc/jco/18/14 15 https://ascopubs.org/toc/jco/18/15 16 https://ascopubs.org/toc/jco/18/16 17 https://ascopubs.org/toc/jco/18/17 18 https://ascopubs.org/toc/jco/18/18 19 https://ascopubs.org/toc/jco/18/19 20 https://ascopubs.org/toc/jco/18/20 21 https://ascopubs.org/toc/jco/18/21 22 https://ascopubs.org/toc/jco/18/22 23 https://ascopubs.org/toc/jco/18/23 24 https://ascopubs.org/toc/jco/18/24
#  45%|████▌     | 18/40 [07:29<12:33, 34.23s/it]
# 1 https://ascopubs.org/toc/jco/19/1 2 https://ascopubs.org/toc/jco/19/2 3 https://ascopubs.org/toc/jco/19/3 4 https://ascopubs.org/toc/jco/19/4 5 https://ascopubs.org/toc/jco/19/5 6 https://ascopubs.org/toc/jco/19/6 7 https://ascopubs.org/toc/jco/19/7 8 https://ascopubs.org/toc/jco/19/8 9 https://ascopubs.org/toc/jco/19/9 10 https://ascopubs.org/toc/jco/19/10 11 https://ascopubs.org/toc/jco/19/11 12 https://ascopubs.org/toc/jco/19/12 13 https://ascopubs.org/toc/jco/19/13 14 https://ascopubs.org/toc/jco/19/14 15 https://ascopubs.org/toc/jco/19/15 16 https://ascopubs.org/toc/jco/19/16 17 https://ascopubs.org/toc/jco/19/17 18 https://ascopubs.org/toc/jco/19/18 19 https://ascopubs.org/toc/jco/19/19 20 https://ascopubs.org/toc/jco/19/20 21 https://ascopubs.org/toc/jco/19/21 22 https://ascopubs.org/toc/jco/19/22 23 https://ascopubs.org/toc/jco/19/23 24 https://ascopubs.org/toc/jco/19/24
#  48%|████▊     | 19/40 [08:14<13:04, 37.36s/it]
# 1 https://ascopubs.org/toc/jco/20/1 2 https://ascopubs.org/toc/jco/20/2 3 https://ascopubs.org/toc/jco/20/3 4 https://ascopubs.org/toc/jco/20/4 5 https://ascopubs.org/toc/jco/20/5 6 https://ascopubs.org/toc/jco/20/6 7 https://ascopubs.org/toc/jco/20/7 8 https://ascopubs.org/toc/jco/20/8 9 https://ascopubs.org/toc/jco/20/9 10 https://ascopubs.org/toc/jco/20/10 11 https://ascopubs.org/toc/jco/20/11 12 https://ascopubs.org/toc/jco/20/12 13 https://ascopubs.org/toc/jco/20/13 14 https://ascopubs.org/toc/jco/20/14 15 https://ascopubs.org/toc/jco/20/15 16 https://ascopubs.org/toc/jco/20/16 17 https://ascopubs.org/toc/jco/20/17 18 https://ascopubs.org/toc/jco/20/18 19 https://ascopubs.org/toc/jco/20/19 20 https://ascopubs.org/toc/jco/20/20 21 https://ascopubs.org/toc/jco/20/21 22 https://ascopubs.org/toc/jco/20/22 23 https://ascopubs.org/toc/jco/20/23 24 https://ascopubs.org/toc/jco/20/24
#  50%|█████     | 20/40 [09:06<13:57, 41.87s/it]
# 1 https://ascopubs.org/toc/jco/21/1 2 https://ascopubs.org/toc/jco/21/2 3 https://ascopubs.org/toc/jco/21/3 4 https://ascopubs.org/toc/jco/21/4 5 https://ascopubs.org/toc/jco/21/5 6 https://ascopubs.org/toc/jco/21/6 7 https://ascopubs.org/toc/jco/21/7 8 https://ascopubs.org/toc/jco/21/8 9 https://ascopubs.org/toc/jco/21/9 10 https://ascopubs.org/toc/jco/21/10 11 https://ascopubs.org/toc/jco/21/11 12 https://ascopubs.org/toc/jco/21/12 13 https://ascopubs.org/toc/jco/21/13 14 https://ascopubs.org/toc/jco/21/14 15 https://ascopubs.org/toc/jco/21/15 16 https://ascopubs.org/toc/jco/21/16 17 https://ascopubs.org/toc/jco/21/17 18 https://ascopubs.org/toc/jco/21/18 19 https://ascopubs.org/toc/jco/21/19 20 https://ascopubs.org/toc/jco/21/20 21 https://ascopubs.org/toc/jco/21/21 22 https://ascopubs.org/toc/jco/21/22 23 https://ascopubs.org/toc/jco/21/23 24 https://ascopubs.org/toc/jco/21/24
#  52%|█████▎    | 21/40 [10:02<14:36, 46.11s/it]
# 1 https://ascopubs.org/toc/jco/22/1 2 https://ascopubs.org/toc/jco/22/2 3 https://ascopubs.org/toc/jco/22/3 4 https://ascopubs.org/toc/jco/22/4 5 https://ascopubs.org/toc/jco/22/5 6 https://ascopubs.org/toc/jco/22/6 7 https://ascopubs.org/toc/jco/22/7 8 https://ascopubs.org/toc/jco/22/8 9 https://ascopubs.org/toc/jco/22/9 10 https://ascopubs.org/toc/jco/22/10 11 https://ascopubs.org/toc/jco/22/11 12 https://ascopubs.org/toc/jco/22/12 13 https://ascopubs.org/toc/jco/22/13 14 https://ascopubs.org/toc/jco/22/14 15 https://ascopubs.org/toc/jco/22/15 16 https://ascopubs.org/toc/jco/22/16 17 https://ascopubs.org/toc/jco/22/17 18 https://ascopubs.org/toc/jco/22/18 19 https://ascopubs.org/toc/jco/22/19 20 https://ascopubs.org/toc/jco/22/20 21 https://ascopubs.org/toc/jco/22/21 22 https://ascopubs.org/toc/jco/22/22 23 https://ascopubs.org/toc/jco/22/23 24 https://ascopubs.org/toc/jco/22/24
#  55%|█████▌    | 22/40 [10:59<14:48, 49.35s/it]
# 1 https://ascopubs.org/toc/jco/23/1 2 https://ascopubs.org/toc/jco/23/2 3 https://ascopubs.org/toc/jco/23/3 4 https://ascopubs.org/toc/jco/23/4 5 https://ascopubs.org/toc/jco/23/5 6 https://ascopubs.org/toc/jco/23/6 7 https://ascopubs.org/toc/jco/23/7 8 https://ascopubs.org/toc/jco/23/8 9 https://ascopubs.org/toc/jco/23/9 10 https://ascopubs.org/toc/jco/23/10 11 https://ascopubs.org/toc/jco/23/11 12 https://ascopubs.org/toc/jco/23/12 13 https://ascopubs.org/toc/jco/23/13 14 https://ascopubs.org/toc/jco/23/14 15 https://ascopubs.org/toc/jco/23/15 16 https://ascopubs.org/toc/jco/23/16 17 https://ascopubs.org/toc/jco/23/17 18 https://ascopubs.org/toc/jco/23/18 19 https://ascopubs.org/toc/jco/23/19 20 https://ascopubs.org/toc/jco/23/20 21 https://ascopubs.org/toc/jco/23/21 22 https://ascopubs.org/toc/jco/23/22 23 https://ascopubs.org/toc/jco/23/23 24 https://ascopubs.org/toc/jco/23/24 25 https://ascopubs.org/toc/jco/23/25 26 https://ascopubs.org/toc/jco/23/26 27 https://ascopubs.org/toc/jco/23/27 28 https://ascopubs.org/toc/jco/23/28 29 https://ascopubs.org/toc/jco/23/29 30 https://ascopubs.org/toc/jco/23/30 31 https://ascopubs.org/toc/jco/23/31 32 https://ascopubs.org/toc/jco/23/32 33 https://ascopubs.org/toc/jco/23/33 34 https://ascopubs.org/toc/jco/23/34 35 https://ascopubs.org/toc/jco/23/35 36 https://ascopubs.org/toc/jco/23/36
#  57%|█████▊    | 23/40 [12:33<17:46, 62.72s/it]
# 1 https://ascopubs.org/toc/jco/24/1 2 https://ascopubs.org/toc/jco/24/2 3 https://ascopubs.org/toc/jco/24/3 4 https://ascopubs.org/toc/jco/24/4 5 https://ascopubs.org/toc/jco/24/5 6 https://ascopubs.org/toc/jco/24/6 7 https://ascopubs.org/toc/jco/24/7 8 https://ascopubs.org/toc/jco/24/8 9 https://ascopubs.org/toc/jco/24/9 10 https://ascopubs.org/toc/jco/24/10 11 https://ascopubs.org/toc/jco/24/11 12 https://ascopubs.org/toc/jco/24/12 13 https://ascopubs.org/toc/jco/24/13 14 https://ascopubs.org/toc/jco/24/14 15 https://ascopubs.org/toc/jco/24/15 16 https://ascopubs.org/toc/jco/24/16 17 https://ascopubs.org/toc/jco/24/17 18 https://ascopubs.org/toc/jco/24/18 19 https://ascopubs.org/toc/jco/24/19 20 https://ascopubs.org/toc/jco/24/20 21 https://ascopubs.org/toc/jco/24/21 22 https://ascopubs.org/toc/jco/24/22 23 https://ascopubs.org/toc/jco/24/23 24 https://ascopubs.org/toc/jco/24/24 25 https://ascopubs.org/toc/jco/24/25 26 https://ascopubs.org/toc/jco/24/26 27 https://ascopubs.org/toc/jco/24/27 28 https://ascopubs.org/toc/jco/24/28 29 https://ascopubs.org/toc/jco/24/29 30 https://ascopubs.org/toc/jco/24/30 31 https://ascopubs.org/toc/jco/24/31 32 https://ascopubs.org/toc/jco/24/32 33 https://ascopubs.org/toc/jco/24/33 34 https://ascopubs.org/toc/jco/24/34 35 https://ascopubs.org/toc/jco/24/35 36 https://ascopubs.org/toc/jco/24/36
#  60%|██████    | 24/40 [13:47<17:36, 66.04s/it]
# 1 https://ascopubs.org/toc/jco/25/1 2 https://ascopubs.org/toc/jco/25/2 3 https://ascopubs.org/toc/jco/25/3 4 https://ascopubs.org/toc/jco/25/4 5 https://ascopubs.org/toc/jco/25/5 6 https://ascopubs.org/toc/jco/25/6 7 https://ascopubs.org/toc/jco/25/7 8 https://ascopubs.org/toc/jco/25/8 9 https://ascopubs.org/toc/jco/25/9 10 https://ascopubs.org/toc/jco/25/10 11 https://ascopubs.org/toc/jco/25/11 12 https://ascopubs.org/toc/jco/25/12 13 https://ascopubs.org/toc/jco/25/13 14 https://ascopubs.org/toc/jco/25/14 15 https://ascopubs.org/toc/jco/25/15 16 https://ascopubs.org/toc/jco/25/16 17 https://ascopubs.org/toc/jco/25/17 18 https://ascopubs.org/toc/jco/25/18 19 https://ascopubs.org/toc/jco/25/19 20 https://ascopubs.org/toc/jco/25/20 21 https://ascopubs.org/toc/jco/25/21 22 https://ascopubs.org/toc/jco/25/22 23 https://ascopubs.org/toc/jco/25/23 24 https://ascopubs.org/toc/jco/25/24 25 https://ascopubs.org/toc/jco/25/25 26 https://ascopubs.org/toc/jco/25/26 27 https://ascopubs.org/toc/jco/25/27 28 https://ascopubs.org/toc/jco/25/28 29 https://ascopubs.org/toc/jco/25/29 30 https://ascopubs.org/toc/jco/25/30 31 https://ascopubs.org/toc/jco/25/31 32 https://ascopubs.org/toc/jco/25/32 33 https://ascopubs.org/toc/jco/25/33 34 https://ascopubs.org/toc/jco/25/34 35 https://ascopubs.org/toc/jco/25/35 36 https://ascopubs.org/toc/jco/25/36
#  62%|██████▎   | 25/40 [15:04<17:22, 69.49s/it]
# 1 https://ascopubs.org/toc/jco/26/1 2 https://ascopubs.org/toc/jco/26/2 3 https://ascopubs.org/toc/jco/26/3 4 https://ascopubs.org/toc/jco/26/4 5 https://ascopubs.org/toc/jco/26/5 6 https://ascopubs.org/toc/jco/26/6 7 https://ascopubs.org/toc/jco/26/7 8 https://ascopubs.org/toc/jco/26/8 9 https://ascopubs.org/toc/jco/26/9 10 https://ascopubs.org/toc/jco/26/10 11 https://ascopubs.org/toc/jco/26/11 12 https://ascopubs.org/toc/jco/26/12 13 https://ascopubs.org/toc/jco/26/13 14 https://ascopubs.org/toc/jco/26/14 15 https://ascopubs.org/toc/jco/26/15 16 https://ascopubs.org/toc/jco/26/16 17 https://ascopubs.org/toc/jco/26/17 18 https://ascopubs.org/toc/jco/26/18 19 https://ascopubs.org/toc/jco/26/19 20 https://ascopubs.org/toc/jco/26/20 21 https://ascopubs.org/toc/jco/26/21 22 https://ascopubs.org/toc/jco/26/22 23 https://ascopubs.org/toc/jco/26/23 24 https://ascopubs.org/toc/jco/26/24 25 https://ascopubs.org/toc/jco/26/25 26 https://ascopubs.org/toc/jco/26/26 27 https://ascopubs.org/toc/jco/26/27 28 https://ascopubs.org/toc/jco/26/28 29 https://ascopubs.org/toc/jco/26/29 30 https://ascopubs.org/toc/jco/26/30 31 https://ascopubs.org/toc/jco/26/31 32 https://ascopubs.org/toc/jco/26/32 33 https://ascopubs.org/toc/jco/26/33 34 https://ascopubs.org/toc/jco/26/34 35 https://ascopubs.org/toc/jco/26/35 36 https://ascopubs.org/toc/jco/26/36
#  65%|██████▌   | 26/40 [16:30<17:21, 74.37s/it]
# 1 https://ascopubs.org/toc/jco/27/1 2 https://ascopubs.org/toc/jco/27/2 3 https://ascopubs.org/toc/jco/27/3 4 https://ascopubs.org/toc/jco/27/4 5 https://ascopubs.org/toc/jco/27/5 6 https://ascopubs.org/toc/jco/27/6 7 https://ascopubs.org/toc/jco/27/7 8 https://ascopubs.org/toc/jco/27/8 9 https://ascopubs.org/toc/jco/27/9 10 https://ascopubs.org/toc/jco/27/10 11 https://ascopubs.org/toc/jco/27/11 12 https://ascopubs.org/toc/jco/27/12 13 https://ascopubs.org/toc/jco/27/13 14 https://ascopubs.org/toc/jco/27/14 15 https://ascopubs.org/toc/jco/27/15 16 https://ascopubs.org/toc/jco/27/16 17 https://ascopubs.org/toc/jco/27/17 18 https://ascopubs.org/toc/jco/27/18 19 https://ascopubs.org/toc/jco/27/19 20 https://ascopubs.org/toc/jco/27/20 21 https://ascopubs.org/toc/jco/27/21 22 https://ascopubs.org/toc/jco/27/22 23 https://ascopubs.org/toc/jco/27/23 24 https://ascopubs.org/toc/jco/27/24 25 https://ascopubs.org/toc/jco/27/25 26 https://ascopubs.org/toc/jco/27/26 27 https://ascopubs.org/toc/jco/27/27 28 https://ascopubs.org/toc/jco/27/28 29 https://ascopubs.org/toc/jco/27/29 30 https://ascopubs.org/toc/jco/27/30 31 https://ascopubs.org/toc/jco/27/31 32 https://ascopubs.org/toc/jco/27/32 33 https://ascopubs.org/toc/jco/27/33 34 https://ascopubs.org/toc/jco/27/34 35 https://ascopubs.org/toc/jco/27/35 36 https://ascopubs.org/toc/jco/27/36
#  68%|██████▊   | 27/40 [17:55<16:46, 77.39s/it]
# 1 https://ascopubs.org/toc/jco/28/1 2 https://ascopubs.org/toc/jco/28/2 3 https://ascopubs.org/toc/jco/28/3 4 https://ascopubs.org/toc/jco/28/4 5 https://ascopubs.org/toc/jco/28/5 6 https://ascopubs.org/toc/jco/28/6 7 https://ascopubs.org/toc/jco/28/7 8 https://ascopubs.org/toc/jco/28/8 9 https://ascopubs.org/toc/jco/28/9 10 https://ascopubs.org/toc/jco/28/10 11 https://ascopubs.org/toc/jco/28/11 12 https://ascopubs.org/toc/jco/28/12 13 https://ascopubs.org/toc/jco/28/13 14 https://ascopubs.org/toc/jco/28/14 15 https://ascopubs.org/toc/jco/28/15 16 https://ascopubs.org/toc/jco/28/16 17 https://ascopubs.org/toc/jco/28/17 18 https://ascopubs.org/toc/jco/28/18 19 https://ascopubs.org/toc/jco/28/19 20 https://ascopubs.org/toc/jco/28/20 21 https://ascopubs.org/toc/jco/28/21 22 https://ascopubs.org/toc/jco/28/22 23 https://ascopubs.org/toc/jco/28/23 24 https://ascopubs.org/toc/jco/28/24 25 https://ascopubs.org/toc/jco/28/25 26 https://ascopubs.org/toc/jco/28/26 27 https://ascopubs.org/toc/jco/28/27 28 https://ascopubs.org/toc/jco/28/28 29 https://ascopubs.org/toc/jco/28/29 30 https://ascopubs.org/toc/jco/28/30 31 https://ascopubs.org/toc/jco/28/31 32 https://ascopubs.org/toc/jco/28/32 33 https://ascopubs.org/toc/jco/28/33 34 https://ascopubs.org/toc/jco/28/34 35 https://ascopubs.org/toc/jco/28/35 36 https://ascopubs.org/toc/jco/28/36
#  70%|███████   | 28/40 [19:16<15:42, 78.53s/it]
# 1 https://ascopubs.org/toc/jco/29/1 2 https://ascopubs.org/toc/jco/29/2 3 https://ascopubs.org/toc/jco/29/3 4 https://ascopubs.org/toc/jco/29/4 5 https://ascopubs.org/toc/jco/29/5 6 https://ascopubs.org/toc/jco/29/6 7 https://ascopubs.org/toc/jco/29/7 8 https://ascopubs.org/toc/jco/29/8 9 https://ascopubs.org/toc/jco/29/9 10 https://ascopubs.org/toc/jco/29/10 11 https://ascopubs.org/toc/jco/29/11 12 https://ascopubs.org/toc/jco/29/12 13 https://ascopubs.org/toc/jco/29/13 14 https://ascopubs.org/toc/jco/29/14 15 https://ascopubs.org/toc/jco/29/15 16 https://ascopubs.org/toc/jco/29/16 17 https://ascopubs.org/toc/jco/29/17 18 https://ascopubs.org/toc/jco/29/18 19 https://ascopubs.org/toc/jco/29/19 20 https://ascopubs.org/toc/jco/29/20 21 https://ascopubs.org/toc/jco/29/21 22 https://ascopubs.org/toc/jco/29/22 23 https://ascopubs.org/toc/jco/29/23 24 https://ascopubs.org/toc/jco/29/24 25 https://ascopubs.org/toc/jco/29/25 26 https://ascopubs.org/toc/jco/29/26 27 https://ascopubs.org/toc/jco/29/27 28 https://ascopubs.org/toc/jco/29/28 29 https://ascopubs.org/toc/jco/29/29 30 https://ascopubs.org/toc/jco/29/30 31 https://ascopubs.org/toc/jco/29/31 32 https://ascopubs.org/toc/jco/29/32 33 https://ascopubs.org/toc/jco/29/33 34 https://ascopubs.org/toc/jco/29/34 35 https://ascopubs.org/toc/jco/29/35 36 https://ascopubs.org/toc/jco/29/36
#  72%|███████▎  | 29/40 [20:40<14:41, 80.14s/it]
# 1 https://ascopubs.org/toc/jco/30/1 2 https://ascopubs.org/toc/jco/30/2 3 https://ascopubs.org/toc/jco/30/3 4 https://ascopubs.org/toc/jco/30/4 5 https://ascopubs.org/toc/jco/30/5 6 https://ascopubs.org/toc/jco/30/6 7 https://ascopubs.org/toc/jco/30/7 8 https://ascopubs.org/toc/jco/30/8 9 https://ascopubs.org/toc/jco/30/9 10 https://ascopubs.org/toc/jco/30/10 11 https://ascopubs.org/toc/jco/30/11 12 https://ascopubs.org/toc/jco/30/12 13 https://ascopubs.org/toc/jco/30/13 14 https://ascopubs.org/toc/jco/30/14 15 https://ascopubs.org/toc/jco/30/15 16 https://ascopubs.org/toc/jco/30/16 17 https://ascopubs.org/toc/jco/30/17 18 https://ascopubs.org/toc/jco/30/18 19 https://ascopubs.org/toc/jco/30/19 20 https://ascopubs.org/toc/jco/30/20 21 https://ascopubs.org/toc/jco/30/21 22 https://ascopubs.org/toc/jco/30/22 23 https://ascopubs.org/toc/jco/30/23 24 https://ascopubs.org/toc/jco/30/24 25 https://ascopubs.org/toc/jco/30/25 26 https://ascopubs.org/toc/jco/30/26 27 https://ascopubs.org/toc/jco/30/27 28 https://ascopubs.org/toc/jco/30/28 29 https://ascopubs.org/toc/jco/30/29 30 https://ascopubs.org/toc/jco/30/30 31 https://ascopubs.org/toc/jco/30/31 32 https://ascopubs.org/toc/jco/30/32 33 https://ascopubs.org/toc/jco/30/33 34 https://ascopubs.org/toc/jco/30/34 35 https://ascopubs.org/toc/jco/30/35 36 https://ascopubs.org/toc/jco/30/36
#  75%|███████▌  | 30/40 [21:53<13:02, 78.21s/it]
# 1 https://ascopubs.org/toc/jco/31/1 2 https://ascopubs.org/toc/jco/31/2 3 https://ascopubs.org/toc/jco/31/3 4 https://ascopubs.org/toc/jco/31/4 5 https://ascopubs.org/toc/jco/31/5 6 https://ascopubs.org/toc/jco/31/6 7 https://ascopubs.org/toc/jco/31/7 8 https://ascopubs.org/toc/jco/31/8 9 https://ascopubs.org/toc/jco/31/9 10 https://ascopubs.org/toc/jco/31/10 11 https://ascopubs.org/toc/jco/31/11 12 https://ascopubs.org/toc/jco/31/12 13 https://ascopubs.org/toc/jco/31/13 14 https://ascopubs.org/toc/jco/31/14 15 https://ascopubs.org/toc/jco/31/15 16 https://ascopubs.org/toc/jco/31/16 17 https://ascopubs.org/toc/jco/31/17 18 https://ascopubs.org/toc/jco/31/18 19 https://ascopubs.org/toc/jco/31/19 20 https://ascopubs.org/toc/jco/31/20 21 https://ascopubs.org/toc/jco/31/21 22 https://ascopubs.org/toc/jco/31/22 23 https://ascopubs.org/toc/jco/31/23 24 https://ascopubs.org/toc/jco/31/24 25 https://ascopubs.org/toc/jco/31/25 26 https://ascopubs.org/toc/jco/31/26 27 https://ascopubs.org/toc/jco/31/27 28 https://ascopubs.org/toc/jco/31/28 29 https://ascopubs.org/toc/jco/31/29 30 https://ascopubs.org/toc/jco/31/30 31 https://ascopubs.org/toc/jco/31/31 32 https://ascopubs.org/toc/jco/31/32 33 https://ascopubs.org/toc/jco/31/33 34 https://ascopubs.org/toc/jco/31/34 35 https://ascopubs.org/toc/jco/31/35 36 https://ascopubs.org/toc/jco/31/36
#  78%|███████▊  | 31/40 [23:06<11:27, 76.37s/it]
# 1 https://ascopubs.org/toc/jco/32/1 2 https://ascopubs.org/toc/jco/32/2 3 https://ascopubs.org/toc/jco/32/3 4 https://ascopubs.org/toc/jco/32/4 5 https://ascopubs.org/toc/jco/32/5 6 https://ascopubs.org/toc/jco/32/6 7 https://ascopubs.org/toc/jco/32/7 8 https://ascopubs.org/toc/jco/32/8 9 https://ascopubs.org/toc/jco/32/9 10 https://ascopubs.org/toc/jco/32/10 11 https://ascopubs.org/toc/jco/32/11 12 https://ascopubs.org/toc/jco/32/12 13 https://ascopubs.org/toc/jco/32/13 14 https://ascopubs.org/toc/jco/32/14 15 https://ascopubs.org/toc/jco/32/15 16 https://ascopubs.org/toc/jco/32/16 17 https://ascopubs.org/toc/jco/32/17 18 https://ascopubs.org/toc/jco/32/18 19 https://ascopubs.org/toc/jco/32/19 20 https://ascopubs.org/toc/jco/32/20 21 https://ascopubs.org/toc/jco/32/21 22 https://ascopubs.org/toc/jco/32/22 23 https://ascopubs.org/toc/jco/32/23 24 https://ascopubs.org/toc/jco/32/24 25 https://ascopubs.org/toc/jco/32/25 26 https://ascopubs.org/toc/jco/32/26 27 https://ascopubs.org/toc/jco/32/27 28 https://ascopubs.org/toc/jco/32/28 29 https://ascopubs.org/toc/jco/32/29 30 https://ascopubs.org/toc/jco/32/30 31 https://ascopubs.org/toc/jco/32/31 32 https://ascopubs.org/toc/jco/32/32 33 https://ascopubs.org/toc/jco/32/33 34 https://ascopubs.org/toc/jco/32/34 35 https://ascopubs.org/toc/jco/32/35 36 https://ascopubs.org/toc/jco/32/36
#  80%|████████  | 32/40 [24:06<09:32, 71.57s/it]
# 1 https://ascopubs.org/toc/jco/33/1 2 https://ascopubs.org/toc/jco/33/2 3 https://ascopubs.org/toc/jco/33/3 4 https://ascopubs.org/toc/jco/33/4 5 https://ascopubs.org/toc/jco/33/5 6 https://ascopubs.org/toc/jco/33/6 7 https://ascopubs.org/toc/jco/33/7 8 https://ascopubs.org/toc/jco/33/8 9 https://ascopubs.org/toc/jco/33/9 10 https://ascopubs.org/toc/jco/33/10 11 https://ascopubs.org/toc/jco/33/11 12 https://ascopubs.org/toc/jco/33/12 13 https://ascopubs.org/toc/jco/33/13 14 https://ascopubs.org/toc/jco/33/14 15 https://ascopubs.org/toc/jco/33/15 16 https://ascopubs.org/toc/jco/33/16 17 https://ascopubs.org/toc/jco/33/17 18 https://ascopubs.org/toc/jco/33/18 19 https://ascopubs.org/toc/jco/33/19 20 https://ascopubs.org/toc/jco/33/20 21 https://ascopubs.org/toc/jco/33/21 22 https://ascopubs.org/toc/jco/33/22 23 https://ascopubs.org/toc/jco/33/23 24 https://ascopubs.org/toc/jco/33/24 25 https://ascopubs.org/toc/jco/33/25 26 https://ascopubs.org/toc/jco/33/26 27 https://ascopubs.org/toc/jco/33/27 28 https://ascopubs.org/toc/jco/33/28 29 https://ascopubs.org/toc/jco/33/29 30 https://ascopubs.org/toc/jco/33/30 31 https://ascopubs.org/toc/jco/33/31 32 https://ascopubs.org/toc/jco/33/32 33 https://ascopubs.org/toc/jco/33/33 34 https://ascopubs.org/toc/jco/33/34 35 https://ascopubs.org/toc/jco/33/35 36 https://ascopubs.org/toc/jco/33/36
#  82%|████████▎ | 33/40 [25:08<08:00, 68.59s/it]
# 1 https://ascopubs.org/toc/jco/34/1 2 https://ascopubs.org/toc/jco/34/2 3 https://ascopubs.org/toc/jco/34/3 4 https://ascopubs.org/toc/jco/34/4 5 https://ascopubs.org/toc/jco/34/5 6 https://ascopubs.org/toc/jco/34/6 7 https://ascopubs.org/toc/jco/34/7 8 https://ascopubs.org/toc/jco/34/8 9 https://ascopubs.org/toc/jco/34/9 10 https://ascopubs.org/toc/jco/34/10 11 https://ascopubs.org/toc/jco/34/11 12 https://ascopubs.org/toc/jco/34/12 13 https://ascopubs.org/toc/jco/34/13 14 https://ascopubs.org/toc/jco/34/14 15 https://ascopubs.org/toc/jco/34/15 16 https://ascopubs.org/toc/jco/34/16 17 https://ascopubs.org/toc/jco/34/17 18 https://ascopubs.org/toc/jco/34/18 19 https://ascopubs.org/toc/jco/34/19 20 https://ascopubs.org/toc/jco/34/20 21 https://ascopubs.org/toc/jco/34/21 22 https://ascopubs.org/toc/jco/34/22 23 https://ascopubs.org/toc/jco/34/23 24 https://ascopubs.org/toc/jco/34/24 25 https://ascopubs.org/toc/jco/34/25 26 https://ascopubs.org/toc/jco/34/26 27 https://ascopubs.org/toc/jco/34/27 28 https://ascopubs.org/toc/jco/34/28 29 https://ascopubs.org/toc/jco/34/29 30 https://ascopubs.org/toc/jco/34/30 31 https://ascopubs.org/toc/jco/34/31 32 https://ascopubs.org/toc/jco/34/32 33 https://ascopubs.org/toc/jco/34/33 34 https://ascopubs.org/toc/jco/34/34 35 https://ascopubs.org/toc/jco/34/35 36 https://ascopubs.org/toc/jco/34/36
#  85%|████████▌ | 34/40 [26:07<06:35, 65.92s/it]
# 1 https://ascopubs.org/toc/jco/35/1 2 https://ascopubs.org/toc/jco/35/2 3 https://ascopubs.org/toc/jco/35/3 4 https://ascopubs.org/toc/jco/35/4 5 https://ascopubs.org/toc/jco/35/5 6 https://ascopubs.org/toc/jco/35/6 7 https://ascopubs.org/toc/jco/35/7 8 https://ascopubs.org/toc/jco/35/8 9 https://ascopubs.org/toc/jco/35/9 10 https://ascopubs.org/toc/jco/35/10 11 https://ascopubs.org/toc/jco/35/11 12 https://ascopubs.org/toc/jco/35/12 13 https://ascopubs.org/toc/jco/35/13 14 https://ascopubs.org/toc/jco/35/14 15 https://ascopubs.org/toc/jco/35/15 16 https://ascopubs.org/toc/jco/35/16 17 https://ascopubs.org/toc/jco/35/17 18 https://ascopubs.org/toc/jco/35/18 19 https://ascopubs.org/toc/jco/35/19 20 https://ascopubs.org/toc/jco/35/20 21 https://ascopubs.org/toc/jco/35/21 22 https://ascopubs.org/toc/jco/35/22 23 https://ascopubs.org/toc/jco/35/23 24 https://ascopubs.org/toc/jco/35/24 25 https://ascopubs.org/toc/jco/35/25 26 https://ascopubs.org/toc/jco/35/26 27 https://ascopubs.org/toc/jco/35/27 28 https://ascopubs.org/toc/jco/35/28 29 https://ascopubs.org/toc/jco/35/29 30 https://ascopubs.org/toc/jco/35/30 31 https://ascopubs.org/toc/jco/35/31 32 https://ascopubs.org/toc/jco/35/32 33 https://ascopubs.org/toc/jco/35/33 34 https://ascopubs.org/toc/jco/35/34 35 https://ascopubs.org/toc/jco/35/35 36 https://ascopubs.org/toc/jco/35/36
#  88%|████████▊ | 35/40 [26:55<05:02, 60.58s/it]
# 1 https://ascopubs.org/toc/jco/36/1 2 https://ascopubs.org/toc/jco/36/2 3 https://ascopubs.org/toc/jco/36/3 4 https://ascopubs.org/toc/jco/36/4 5 https://ascopubs.org/toc/jco/36/5 6 https://ascopubs.org/toc/jco/36/6 7 https://ascopubs.org/toc/jco/36/7 8 https://ascopubs.org/toc/jco/36/8 9 https://ascopubs.org/toc/jco/36/9 10 https://ascopubs.org/toc/jco/36/10 11 https://ascopubs.org/toc/jco/36/11 12 https://ascopubs.org/toc/jco/36/12 13 https://ascopubs.org/toc/jco/36/13 14 https://ascopubs.org/toc/jco/36/14 15 https://ascopubs.org/toc/jco/36/15 16 https://ascopubs.org/toc/jco/36/16 17 https://ascopubs.org/toc/jco/36/17 18 https://ascopubs.org/toc/jco/36/18 19 https://ascopubs.org/toc/jco/36/19 20 https://ascopubs.org/toc/jco/36/20 21 https://ascopubs.org/toc/jco/36/21 22 https://ascopubs.org/toc/jco/36/22 23 https://ascopubs.org/toc/jco/36/23 24 https://ascopubs.org/toc/jco/36/24 25 https://ascopubs.org/toc/jco/36/25 26 https://ascopubs.org/toc/jco/36/26 27 https://ascopubs.org/toc/jco/36/27 28 https://ascopubs.org/toc/jco/36/28 29 https://ascopubs.org/toc/jco/36/29 30 https://ascopubs.org/toc/jco/36/30 31 https://ascopubs.org/toc/jco/36/31 32 https://ascopubs.org/toc/jco/36/32 33 https://ascopubs.org/toc/jco/36/33 34 https://ascopubs.org/toc/jco/36/34 35 https://ascopubs.org/toc/jco/36/35 36 https://ascopubs.org/toc/jco/36/36
#  90%|█████████ | 36/40 [27:38<03:40, 55.18s/it]
# 1 https://ascopubs.org/toc/jco/37/1 2 https://ascopubs.org/toc/jco/37/2 3 https://ascopubs.org/toc/jco/37/3 4 https://ascopubs.org/toc/jco/37/4 5 https://ascopubs.org/toc/jco/37/5 6 https://ascopubs.org/toc/jco/37/6 7 https://ascopubs.org/toc/jco/37/7 8 https://ascopubs.org/toc/jco/37/8 9 https://ascopubs.org/toc/jco/37/9 10 https://ascopubs.org/toc/jco/37/10 11 https://ascopubs.org/toc/jco/37/11 12 https://ascopubs.org/toc/jco/37/12 13 https://ascopubs.org/toc/jco/37/13 14 https://ascopubs.org/toc/jco/37/14 15 https://ascopubs.org/toc/jco/37/15 16 https://ascopubs.org/toc/jco/37/16 17 https://ascopubs.org/toc/jco/37/17 18 https://ascopubs.org/toc/jco/37/18 19 https://ascopubs.org/toc/jco/37/19 20 https://ascopubs.org/toc/jco/37/20 21 https://ascopubs.org/toc/jco/37/21 22 https://ascopubs.org/toc/jco/37/22 23 https://ascopubs.org/toc/jco/37/23 24 https://ascopubs.org/toc/jco/37/24 25 https://ascopubs.org/toc/jco/37/25 26 https://ascopubs.org/toc/jco/37/26 27 https://ascopubs.org/toc/jco/37/27 28 https://ascopubs.org/toc/jco/37/28 29 https://ascopubs.org/toc/jco/37/29 30 https://ascopubs.org/toc/jco/37/30 31 https://ascopubs.org/toc/jco/37/31 32 https://ascopubs.org/toc/jco/37/32 33 https://ascopubs.org/toc/jco/37/33 34 https://ascopubs.org/toc/jco/37/34 35 https://ascopubs.org/toc/jco/37/35 36 https://ascopubs.org/toc/jco/37/36
#  92%|█████████▎| 37/40 [28:12<02:26, 48.83s/it]
# 1 https://ascopubs.org/toc/jco/38/1 2 https://ascopubs.org/toc/jco/38/2 3 https://ascopubs.org/toc/jco/38/3 4 https://ascopubs.org/toc/jco/38/4 5 https://ascopubs.org/toc/jco/38/5 6 https://ascopubs.org/toc/jco/38/6 7 https://ascopubs.org/toc/jco/38/7 8 https://ascopubs.org/toc/jco/38/8 9 https://ascopubs.org/toc/jco/38/9 10 https://ascopubs.org/toc/jco/38/10 11 https://ascopubs.org/toc/jco/38/11 12 https://ascopubs.org/toc/jco/38/12 13 https://ascopubs.org/toc/jco/38/13 14 https://ascopubs.org/toc/jco/38/14 15 https://ascopubs.org/toc/jco/38/15 16 https://ascopubs.org/toc/jco/38/16 17 https://ascopubs.org/toc/jco/38/17 18 https://ascopubs.org/toc/jco/38/18 19 https://ascopubs.org/toc/jco/38/19 20 https://ascopubs.org/toc/jco/38/20 21 https://ascopubs.org/toc/jco/38/21 22 https://ascopubs.org/toc/jco/38/22 23 https://ascopubs.org/toc/jco/38/23 24 https://ascopubs.org/toc/jco/38/24 25 https://ascopubs.org/toc/jco/38/25 26 https://ascopubs.org/toc/jco/38/26 27 https://ascopubs.org/toc/jco/38/27 28 https://ascopubs.org/toc/jco/38/28 29 https://ascopubs.org/toc/jco/38/29 30 https://ascopubs.org/toc/jco/38/30 31 https://ascopubs.org/toc/jco/38/31 32 https://ascopubs.org/toc/jco/38/32 33 https://ascopubs.org/toc/jco/38/33 34 https://ascopubs.org/toc/jco/38/34 35 https://ascopubs.org/toc/jco/38/35 36 https://ascopubs.org/toc/jco/38/36
#  95%|█████████▌| 38/40 [28:49<01:30, 45.40s/it]
# 1 https://ascopubs.org/toc/jco/39/1 2 https://ascopubs.org/toc/jco/39/2 3 https://ascopubs.org/toc/jco/39/3 4 https://ascopubs.org/toc/jco/39/4 5 https://ascopubs.org/toc/jco/39/5 6 https://ascopubs.org/toc/jco/39/6 7 https://ascopubs.org/toc/jco/39/7 8 https://ascopubs.org/toc/jco/39/8 9 https://ascopubs.org/toc/jco/39/9 10 https://ascopubs.org/toc/jco/39/10 11 https://ascopubs.org/toc/jco/39/11 12 https://ascopubs.org/toc/jco/39/12 13 https://ascopubs.org/toc/jco/39/13 14 https://ascopubs.org/toc/jco/39/14 15 https://ascopubs.org/toc/jco/39/15 16 https://ascopubs.org/toc/jco/39/16 17 https://ascopubs.org/toc/jco/39/17 18 https://ascopubs.org/toc/jco/39/18 19 https://ascopubs.org/toc/jco/39/19 20 https://ascopubs.org/toc/jco/39/20 21 https://ascopubs.org/toc/jco/39/21 22 https://ascopubs.org/toc/jco/39/22 23 https://ascopubs.org/toc/jco/39/23 24 https://ascopubs.org/toc/jco/39/24 25 https://ascopubs.org/toc/jco/39/25 26 https://ascopubs.org/toc/jco/39/26 27 https://ascopubs.org/toc/jco/39/27 28 https://ascopubs.org/toc/jco/39/28 29 https://ascopubs.org/toc/jco/39/29 30 https://ascopubs.org/toc/jco/39/30 31 https://ascopubs.org/toc/jco/39/31 32 https://ascopubs.org/toc/jco/39/32 33 https://ascopubs.org/toc/jco/39/33 34 https://ascopubs.org/toc/jco/39/34 35 https://ascopubs.org/toc/jco/39/35 36 https://ascopubs.org/toc/jco/39/36
#  98%|█████████▊| 39/40 [29:36<00:45, 45.87s/it]
# 1 https://ascopubs.org/toc/jco/40/1 2 https://ascopubs.org/toc/jco/40/2 3 https://ascopubs.org/toc/jco/40/3 4 https://ascopubs.org/toc/jco/40/4 5 https://ascopubs.org/toc/jco/40/5 6 https://ascopubs.org/toc/jco/40/6 7 https://ascopubs.org/toc/jco/40/7 8 https://ascopubs.org/toc/jco/40/8 9 https://ascopubs.org/toc/jco/40/9 10 https://ascopubs.org/toc/jco/40/10 11 https://ascopubs.org/toc/jco/40/11 12 https://ascopubs.org/toc/jco/40/12 13 https://ascopubs.org/toc/jco/40/13 14 https://ascopubs.org/toc/jco/40/14 15 https://ascopubs.org/toc/jco/40/15 16 https://ascopubs.org/toc/jco/40/16 17 https://ascopubs.org/toc/jco/40/17 18 https://ascopubs.org/toc/jco/40/18 19 https://ascopubs.org/toc/jco/40/19 20 https://ascopubs.org/toc/jco/40/20 21 https://ascopubs.org/toc/jco/40/21 22 https://ascopubs.org/toc/jco/40/22 23 https://ascopubs.org/toc/jco/40/23 24 https://ascopubs.org/toc/jco/40/24 25 https://ascopubs.org/toc/jco/40/25 26 https://ascopubs.org/toc/jco/40/26 27 https://ascopubs.org/toc/jco/40/27
# 100%|██████████| 40/40 [30:07<00:00, 45.19s/it]

# %%
# creatting a single list of all type of data
all_titles = []
all_authors = []
all_articles = []
all_years = []
year = 1983
for item in data:
    for year_data in item:
        all_titles += year_data[0]
        all_authors += year_data[1]
        all_articles += year_data[2]
        all_years += [str(year) for x in range(len(year_data[0]))]
    year += 1

# creating a dictionary of data
data_dic = {'title':all_titles, 'author': all_authors, 'pdf_url':all_articles, 'year':all_years}

# %%
print(len(all_titles))
print(len(all_authors))
print(len(all_articles))
print(len(all_years))
# Out:
# 27325
# 27325
# 27325
# 27325

# %%
df = pd.DataFrame(data_dic)
df.head(10)
# Out:
#                                                title          author  \
# 0                          A Journal for Oncologists
# 1  Adjuvant CMF in breast cancer: comparative 5-y...  Tancini et al.
# 2  Histologic conversion in the non-Hodgkin's lym...    Acker et al.
# 3  Feasibility study of combining metronidazole w...  Stewart et al.
# 4  Constant infusion schedule for adriamycin: a p...   Lokich et al.
# 5  Serum cyclophosphamide activity in patients tr...   Sarpel et al.
# 6  Scalp hypothermia: a comparison of ice packs a...     Dean et al.
# 7  Evaluation of prognostic factors in chemothera...    Eagan et al.
# 8  The response of Ewing's sarcoma to sequential ...    Hayes et al.
# 9  Methylglyoxal-bis(guanylhydrazone) (Methyl-GAG...  Warrell et al.
#
#                                              pdf_url  year
# 0  https://ascopubs.org/doi/pdf/10.1200/JCO.1983....  1983
# 1  https://ascopubs.org/doi/pdf/10.1200/JCO.1983....  1983
# 2  https://ascopubs.org/doi/pdf/10.1200/JCO.1983....  1983
# 3  https://ascopubs.org/doi/pdf/10.1200/JCO.1983....  1983
# 4  https://ascopubs.org/doi/pdf/10.1200/JCO.1983....  1983
# 5  https://ascopubs.org/doi/pdf/10.1200/JCO.1983....  1983
# 6  https://ascopubs.org/doi/pdf/10.1200/JCO.1983....  1983
# 7  https://ascopubs.org/doi/pdf/10.1200/JCO.1983....  1983
# 8  https://ascopubs.org/doi/pdf/10.1200/JCO.1983....  1983
# 9  https://ascopubs.org/doi/pdf/10.1200/JCO.1983....  1983

# %%
df.to_csv("data.csv", index=False)

# %%
# read csv file 
df_data = pd.read_csv("data.csv")
df_data.shape
# Out:
# (27325, 4)

# %%
df_data.head()
# Out:
#                                                title          author  \
# 0                          A Journal for Oncologists             NaN
# 1  Adjuvant CMF in breast cancer: comparative 5-y...  Tancini et al.
# 2  Histologic conversion in the non-Hodgkin's lym...    Acker et al.
# 3  Feasibility study of combining metronidazole w...  Stewart et al.
# 4  Constant infusion schedule for adriamycin: a p...   Lokich et al.
#
#                                              pdf_url  year
# 0  https://ascopubs.org/doi/pdf/10.1200/JCO.1983....  1983
# 1  https://ascopubs.org/doi/pdf/10.1200/JCO.1983....  1983
# 2  https://ascopubs.org/doi/pdf/10.1200/JCO.1983....  1983
# 3  https://ascopubs.org/doi/pdf/10.1200/JCO.1983....  1983
# 4  https://ascopubs.org/doi/pdf/10.1200/JCO.1983....  1983

# %%
# remove columns with NaN values 
df_data = df_data.dropna()
df_data.head()
# Out:
#                                                title          author  \
# 1  Adjuvant CMF in breast cancer: comparative 5-y...  Tancini et al.
# 2  Histologic conversion in the non-Hodgkin's lym...    Acker et al.
# 3  Feasibility study of combining metronidazole w...  Stewart et al.
# 4  Constant infusion schedule for adriamycin: a p...   Lokich et al.
# 5  Serum cyclophosphamide activity in patients tr...   Sarpel et al.
#
#                                              pdf_url  year
# 1  https://ascopubs.org/doi/pdf/10.1200/JCO.1983....  1983
# 2  https://ascopubs.org/doi/pdf/10.1200/JCO.1983....  1983
# 3  https://ascopubs.org/doi/pdf/10.1200/JCO.1983....  1983
# 4  https://ascopubs.org/doi/pdf/10.1200/JCO.1983....  1983
# 5  https://ascopubs.org/doi/pdf/10.1200/JCO.1983....  1983

# %%
# remove the rows with empty title
df_data = df_data[df_data["title"] != ""]
df_data.head()
df_data.shape

# remove the rows with empty author
df_data = df_data[df_data["author"] != ""]
df_data.shape

# remove the rows with empty pdf_url
df_data = df_data[df_data["pdf_url"] != ""]
df_data.shape
# Out:
# (26245, 4)

# %%
# remove "et al." from the author column
df_data["author"] = df_data["author"].str.replace("et al.", "")
df_data.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#                                                title    author  \
# 1  Adjuvant CMF in breast cancer: comparative 5-y...  Tancini
# 2  Histologic conversion in the non-Hodgkin's lym...    Acker
# 3  Feasibility study of combining metronidazole w...  Stewart
# 4  Constant infusion schedule for adriamycin: a p...   Lokich
# 5  Serum cyclophosphamide activity in patients tr...   Sarpel
#
#                                              pdf_url  year
# 1  https://ascopubs.org/doi/pdf/10.1200/JCO.1983....  1983
# 2  https://ascopubs.org/doi/pdf/10.1200/JCO.1983....  1983
# 3  https://ascopubs.org/doi/pdf/10.1200/JCO.1983....  1983
# 4  https://ascopubs.org/doi/pdf/10.1200/JCO.1983....  1983
# 5  https://ascopubs.org/doi/pdf/10.1200/JCO.1983....  1983

# %%
# find the unique authors
unique_authors = df_data["author"].unique()
print(len(unique_authors)  )

# find the unique titles
unique_titles = df_data["title"].unique()
print(len(unique_titles))

# find the unique pdf_urls
unique_pdf_urls = df_data["pdf_url"].unique()
print(len(unique_pdf_urls))

# find the unique years
unique_years = df_data["year"].unique()
print(len(unique_years))
# Out:
# 11493
# 25051
# 26114
# 40

# %%
# make a column for the title
df_data["title"] = df_data["title"].str.lower()
df_data.head()
# store tilte col in a list
title_list = df_data["title"].tolist()
title_list
# Out:
# ['adjuvant cmf in breast cancer: comparative 5-year results of 12 versus 6 cycles.',
#  "histologic conversion in the non-hodgkin's lymphomas.",
#  'feasibility study of combining metronidazole with chemotherapy.',
#  'constant infusion schedule for adriamycin: a phase i-ii clinical trial of a 30-day schedule by ambulatory pump delivery system.',
#  'serum cyclophosphamide activity in patients treated for small cell carcinoma of the lung.',
#  'scalp hypothermia: a comparison of ice packs and the kold kap in the prevention of doxorubicin-induced alopecia.',
#  'evaluation of prognostic factors in chemotherapy of recurrent brain tumors.',
#  "the response of ewing's sarcoma to sequential cyclophosphamide and adriamycin induction therapy.",
#  'methylglyoxal-bis(guanylhydrazone) (methyl-gag): current status and future prospects.',
#  'reflections on medical oncology: an appeal for better clinical trials and improved reporting of their results.',
#  'karnofsky memorial lecture. breaking the cure barrier.',
#  'improved prognosis of diffuse histiocytic and undifferentiated lymphoma by use of high dose methotrexate alternating with standard agents (m-bacod).',
#  'intramedullary spinal cord metastases from small cell carcinoma of the lung.',
#  'phase i-ii studies of oral tegafur (ftorafur).',
#  'the use of different induction and maintenance chemotherapy regimens for the treatment of advanced yolk sac tumors.',
#  "the in vivo effect of thymic factor (thymostimulin) administration on circulating immune complexes and serum lysozyme levels in untreated hodgkin's disease patients.",
#  'a multifactorial analysis of melanoma. iv. prognostic factors in 200 melanoma patients with distant metastases (stage iii).',
#  'methyl-ccnu, 5-fluorouracil, vincristine, and streptozocin (mof-strep) in metastatic colo-rectal carcinoma.',
#  'a randomized trial of five and three drug chemotherapy and chemoimmunotherapy in women with operable node positive breast cancer.',
#  "a dose and time response analysis of the treatment of hodgkin's disease with mopp chemotherapy.",
#  'guidelines for publishing papers on cancer clinical trials: responsibilities of editors and authors.',
#  'stage ii nonseminomatous testicular cancer: a 10-year experience.',
#  'fertility after chemotherapy for testicular cancer.',
#  'clinical-pathologic study of early breast cancer treated by primary radiation therapy.',
#  'chronic lymphocytic leukemia and other chronic lymphoid proliferations: surface marker phenotypes and clinical correlations.',
#  'clinical trial of the effect of s-2-(3-aminopropylamino)-ethylphosphorothioic acid (wr-2721) (nsc 296961) on the toxicity of cyclophosphamide.',
#  'effective chemotherapy of acute myelocytic leukemia occurring after alkylating agent or radiation therapy for prior malignancy.',
#  'methotrexate-induced renal impairment: clinical studies and rescue from systemic toxicity with high-dose leucovorin and thymidine.',
#  'effects of cloned human leukocyte interferons in the human tumor stem cell assay.',
#  'influence of tumor estrogen and progesterone receptor levels on the response to tamoxifen and chemotherapy in primary breast cancer.',
#  'failure of low-dose, total-body irradiation to augment combination chemotherapy in extensive-stage small cell carcinoma of the lung.',
#  'combination chemotherapy with cis-diamminedichloroplatinum and vinblastine in advanced non-small cell lung cancer.',
#  'osteogenic sarcoma: alterations in the pattern of pulmonary metastases with adjuvant chemotherapy.',
#  'comparison of extramedullary plasmacytomas with solitary and multiple plasma cell tumors of bone.',
#  'large cell lymphomas of the stomach: improved prognosis with complete resection of all intrinsic gastrointestinal disease.',
#  'mycosis fungoides: subcutaneous and visceral tumors, orbital involvement, and ophthalmoplegia.',
#  'functional organization of the hematopoietic stem cell compartment: implications for cancer and its therapy.',
#  'implantable pumps--opportunities for improved therapy of malignant disease.',
#  'diagnostic accuracies of clinical studies in patients with small cell carcinoma of the lung.',
#  'randomized study of cyclophosphamide, doxorubicin, and etoposide (vp16-213) with or without cisplatinum in non-small cell lung cancer.',
#  'trimethoprim/sulfamethoxazole versus placebo: a double-blind comparison of infection prophylaxis in patients with small cell carcinoma of the lung.',
#  'randomized study of 3 years versus 5 years of chemotherapy in childhood acute lymphoblastic leukemia.',
#  'reduction in central nervous system leukemia with a pharmacokinetically derived intrathecal methotrexate dosage regimen.',
#  "end results of treating children with localized non-hodgkin's lymphomas with a combined modality approach of lessened intensity.",
#  'phase i study of spirogermanium given daily.',
#  'long-term hepatic arterial infusion of 5-fluorodeoxyuridine for liver metastases using an implantable infusion pump.',
#  'breast cancer estrogen and progesterone receptor values: their distribution, degree of concordance, and relation to number of positive axillary nodes.',
#  'intensive melphalan chemotherapy and cryopreserved autologous bone marrow transplantation for the treatment of refractory cancer.',
#  'doxorubicin, mitomycin-c, and 5-fluorouracil (dmf) in the treatment of metastatic hormonal refractory adenocarcinoma of the prostate, with a note on the staging of metastatic prostate cancer.',
#  'sequential changes in platelet function and coagulation in leukemic children treated with l-asparaginase, prednisone, and vincristine.',
#  'peritoneal mesothelioma: natural history and response to chemotherapy.',
#  'transient left homonymous hemianopsia and encephalopathy following treatment of testicular carcinoma with cisplatinum, vinblastine, and bleomycin.',
#  'phase i trial of retinol in cancer patients.',
#  'local or regionally recurrent carcinoma of the breast: results of therapy in 121 patients.',
#  'survival of women with metastatic breast cancer at yale from 1920 to 1980.',
#  'combination chemotherapy for locally advanced pancreatic cancer: equivalence to external beam irradiation and implication for future management.',
#  'painful gynecomastia following cytotoxic therapy for testis cancer: a potentially favorable prognostic sign?',
#  'cisplatin-vincristine-bleomycin therapy in squamous cell carcinoma of the head and neck.',
#  'treatment of primary osteosarcoma with intra-arterial and intravenous high-dose methotrexate.',
#  "long-term follow-up with abdic salvage chemotherapy of mopp-resistant hodgkin's disease.",
#  "review of the use of marrow transplantation in the treatment of non-hodgkin's lymphoma.",
#  'alternating combination chemotherapy and levamisole improves survival in multiple myeloma: a southwest oncology group study.',
#  'treatment of acute lymphoblastic leukemia in adults: results of the l-10 and l-10m protocols.',
#  'second central nervous system prophylaxis in children with acute lymphoblastic leukemia who relapse after elective cessation of therapy.',
#  'weekly doxorubicin in endocrine-refractory carcinoma of the prostate.',
#  'treatment of small cell lung cancer with vp-16, vincristine, doxorubicin (adriamycin), cyclophosphamide (evac), and high-dose chest radiotherapy.',
#  "extraskeletal ewing's sarcoma: results of combined modality treatment.",
#  'human tumor cell heterogeneity and metastasis.',
#  'progress in the treatment of plasma cell myeloma?',
#  'patients with secondary acute myelocytic leukemia (aml) receiving "timed" sequential chemotherapy.',
#  'long-term remissions in lymphoblastic lymphoma.',
#  'karnofsky memorial lecture. marrow transplantation for malignant diseases.',
#  "predictive value of lymphography for sites of subdiaphragmatic disease encountered at staging laparotomy in newly diagnosed hodgkin's disease and non-hodgkin's lymphoma.",
#  'long-term results of the apo protocol (vincristine, doxorubicin [adriamycin], and prednisone) for treatment of mediastinal lymphoblastic lymphoma.',
#  'cranial nerve involvement in children with leukemia and lymphoma.',
#  'effect of dose and schedule on pharmacokinetics of high-dose cytosine arabinoside in plasma and cerebrospinal fluid.',
#  'a technique to quantify cytoreduction in the bone marrow induced by cytotoxic chemotherapy.',
#  'four-drug combination chemotherapy (methotrexate, cyclophosphamide, hexamethylmelamine, and ccnu) for non-small cell bronchogenic carcinoma: a cancer and leukemia group b study.',
#  'late relapse of testicular cancer.',
#  'local installation of small doses of streptokinase for treatment of thrombotic occlusions of long-term access catheters.',
#  'involvement of the genitourinary system in multiple primary malignant neoplasms: a review.',
#  'monoclonal antibodies in cancer therapy.',
#  "siop (international society of paediatric oncology) and the management of wilms' tumor.",
#  "effectiveness of preoperative chemotherapy in wilms' tumor: results of an international society of paediatric oncology (siop) clinical trial.",
#  'autologous bone-marrow transplantation: host effects of high-dose bcnu.',
#  'phase i study of carboplatin given on a five-day intravenous schedule.',
#  'marrow cytogenetic and cell-culture analyses of the myelodysplastic syndromes: insights to pathophysiology and prognosis.',
#  'adrenocorticotropic hormone in the prevention of cisplatin-induced nausea and vomiting.',
#  'a comparison of the quality of participation of community affiliates and that of universities in the northern california oncology group.',
#  'combination cisplatin, vinblastine, and bleomycin chemotherapy (pvb) for malignant germ-cell tumors of the ovary.',
#  'hairy cell leukemia: lessons learned in twenty-five years.',
#  'oncogenic genes and their potential role in human malignancy.',
#  'study on the comparability of 6 versus 12 cycles of adjuvant cyclophosphamide, methotrexate, and fluorouracil.',
#  'alternating combination chemotherapy and levamisole improves survival in multiple myeloma',
#  'philadelphia chromosome and terminal transferase-positive acute leukemia: similarity of terminal phase of chronic myelogenous leukemia and de novo acute presentation.',
#  "central nervous system involvement in american burkitt's lymphoma.",
#  "extralymphatic involvement in diffuse non-hodgkin's lymphoma.",
#  "high-dose cytosine arabinoside in non-hodgkin's lymphoma.",
#  'malignant mesothelioma following radiation exposure.',
#  'high-dose vp-16-213 and autologous bone marrow transplantation for refractory malignancies: a phase i study.',
#  'chemotherapy of refractory germ cell cancer with etoposide.',
#  'analysis of survival by tumor response.',
#  'a multifactorial analysis of prognostic factors in patients with liver metastases from colorectal carcinoma.',
#  'treatment of the carcinoid tumor and the malignant carcinoid syndrome.',
#  'age and therapy in women with breast cancer.',
#  "the treatment of stage iiia hodgkin's disease.",
#  'phase ii study of doxifluridine in advanced colorectal adenocarcinoma.',
#  'clinical pharmacokinetics of intraarterial cisplatin in humans.',
#  'alteration of the pharmacokinetics of high-dose ara-c by its metabolite, high ara-u in patients with acute leukemia.',
#  'treatment of advanced breast cancer with mitomycin c combined with vinblastine or vindesine.',
#  'multivariate analysis of prognostic factors in metastatic breast cancer.',
#  'prospective randomized trial of one-hour sequential versus simultaneous methotrexate plus 5-fluorouracil in advanced and recurrent squamous cell head and neck cancer.',
#  'serial cranial computed-tomography scans in children with leukemia given two different forms of central nervous system therapy.',
#  'circulating immune complexes in childhood malignancies: a pediatric oncology group study.',
#  'high-dose methotrexate as part of remission maintenance therapy for childhood acute lymphocytic leukemia: a pediatric oncology group pilot study.',
#  'the influential t cell in b-cell neoplasms.',
#  'second central nervous system prophylaxis in children with acute lymphoblastic leukemia who relapse after elective cessation of therapy',
#  'gene amplification in a leukemic patient treated with methotrexate.',
#  'cytologic evidence for gene amplification in methotrexate-resistant cells obtained from a patient with ovarian adenocarcinoma.',
#  'resistance to methotrexate due to gene amplification in a patient with acute leukemia.',
#  'the impact of primary irradiation treatment of localized breast cancer on the ability to administer systemic adjuvant chemotherapy.',
#  'a randomized attempt to increase the efficacy of cytotoxic chemotherapy in metastatic breast cancer by hormonal synchronization.',
#  'time course and prognosis of local recurrence following primary radiation therapy for early breast cancer.',
#  'the true predictive value of the human tumor stem cell assay: does a workable assay select for treatment responders?',
#  'human tumor clonogenic assay in patients with unknown primary carcinomas.',
#  'serum beta 2-microglobulin in the initial staging and subsequent monitoring of monoclonal plasma cell disorders.',
#  'elevated myelin basic protein levels in the cerebrospinal fluid of children with acute lymphoblastic leukemia.',
#  'gene amplification in drug resistance: of mice and men.',
#  'bone marrow transplantation and salvage chemotherapy.',
#  'cancer of the esophagus: a brighter future?',
#  'preoperative chemotherapy and radiation therapy for patients with cancer of the esophagus: a potentially curative approach.',
#  "childhood hodgkin's disease: patterns of relapse.",
#  "the treatment of localized non-hodgkin's lymphoma in children: a report from the children's cancer study group.",
#  'sequential combination of systemic high-dose ara-c and asparaginase for the treatment of central nervous system leukemia and lymphoma.',
#  'prediction of complete remission in patients with refractory acute leukemia treated with amsa.',
#  'identification of early relapsing patients with adult acute nonlymphocytic leukemia by bone marrow biopsy after initial induction chemotherapy.',
#  'a comparison of cardiac biopsy grades and ejection fraction estimations in patients receiving adriamycin.',
#  'ethiodized oil emulsion 13 in computed tomography of hepatoma.',
#  'phase i trial and pharmacokinetic studies of alpha-difluoromethylornithine--an inhibitor of polyamine biosynthesis.',
#  'a rational clinical staging system for childhood rhabdomyosarcoma.',
#  "therapy of localized non-hodgkin's lymphoma in children.",
#  "adjuvant chemotherapy in osteogenic sarcoma: the triumph that isn't?",
#  'the treatment of locally advanced breast cancer.',
#  'a controlled pilot study of high-dose methotrexate as postsurgical adjuvant treatment for primary osteosarcoma.',
#  'aggressive combined modality therapy for advanced local-regional breast carcinoma.',
#  'randomized phase iii trial of vinblastine, bleomycin, and cis-dichlorodiammine-platinum versus dacarbazine in malignant melanoma.',
#  'brain metastases in patients with renal cell carcinoma: prognosis and treatment.',
#  'prognostic factors influencing survival of patients with advanced colorectal cancer: hepatic-artery infusion versus systemic intravenous chemotherapy for liver metastases.',
#  'criteria for monitoring carcinoembryonic antigen: variability of sequential assays at elevated levels.',
#  'karnofsky performance status revisited: reliability, validity, and guidelines.',
#  "prognostic significance of erythrocyte sedimentation rate in clinical stages i-ii of hodgkin's disease.",
#  'small cell bronchogenic carcinoma: factors associated with pneumonia during chemotherapy.',
#  'increased therapeutic index of weekly doxorubicin in the therapy of non-small cell lung cancer: a prospective, randomized study.',
#  'penetration of vp 16-213 into cerebrospinal fluid after high-dose intravenous administration.',
#  'comparison of the biologic effects of two recombinant human interferons alpha (ra and rd) in humans.',
#  'polar solvents: a novel class of antineoplastic agents.',
#  'contributions of host- and disease-related attributes to the outcome of patients with acute myelogenous leukemia.',
#  'clinical features and results of management of superior vena cava syndrome secondary to lymphoma.',
#  'orchiectomy alone in the treatment of clinical stage i nonseminomatous germ cell tumor of the testis.',
#  'high-dose vp-16-213 monotherapy for refractory germinal malignancies: a phase ii study.',
#  "randomized phase ii trial of carminomycin versus 4'-epidoxorubicin in advanced breast cancer.",
#  'antitumor activity of esorubicin in human tumor clonogenic assay with comparisons to doxorubicin.',
#  'relationships of body size with breast cancer.',
#  'combined modality induction therapy without maintenance chemotherapy for small cell carcinoma of the lung.',
#  'the natural history of gastric cancer and prognostic factors influencing survival.',
#  'activity of sequential low-dose methotrexate and fluorouracil in advanced colorectal carcinoma: attempt at correlation with tissue and blood levels of phosphoribosylpyrophosphate.',
#  'vindesine in patients with metastatic malignant melanoma: a southwest oncology group study.',
#  'effective control of chemotherapy-induced nausea and vomiting with oral prednisone and metoclopramide.',
#  'glucocorticoid receptors in leukemia and lymphoma.',
#  'the current status of therapy for and prevention of blast crisis of chronic myelocytic leukemia.',
#  'interferons in the treatment of human cancer.',
#  'treatment of meningeal leukemia.',
#  'treatment of meningeal relapse in childhood acute lymphoblastic leukemia. i. results of craniospinal irradiation.',
#  'successful treatment of meningeal leukemia using systemic high-dose cytosine arabinoside.',
#  'a critical comparison of allogeneic bone marrow transplantation and conventional chemotherapy as treatment for acute nonlymphocytic leukemia.',
#  'intensive chemotherapy, total body irradiation, and autologous marrow transplantation for chronic granulocytic leukemia-blast phase: report of four additional cases.',
#  'increased incidence of acute nonlymphocytic leukemia following therapy in patients with small cell carcinoma of the lung.',
#  'randomized phase iii comparison of three doxorubicin-based chemotherapy regimens in advanced non-small cell lung cancer: a southeastern cancer study group trial.',
#  'chemotherapy-induced interstitial pneumonitis during treatment of small cell anaplastic lung cancer.',
#  'phase i and ii trial of five-day infused 5-fluorouracil and radiation in advanced cancer of the head and neck.',
#  'randomized trial of low- versus high-dose medroxyprogesterone acetate in the induction treatment of postmenopausal patients with advanced breast cancer.',
#  'drug combinations in the treatment of gastric adenocarcinoma: a randomized southwest oncology group study.',
#  'prognostic significance of complete surgical resection of pulmonary metastases in patients with osteogenic sarcoma: analysis of 32 patients.',
#  'etoposide (vp-16-213) in malignant brain tumors: a phase ii study.',
#  'hemolytic transfusion reactions in oncology patients: experience in a large cancer center.',
#  'endomyocardial biopsy to monitor anthracycline therapy in children.',
#  'malignant mesothelioma of the tunica vaginalis testis.',
#  'angiotensin-i-converting enzyme in cancer patients.',
#  'a comparison of fast homoarginine-sensitive alkaline phosphatase and carcinoembryonic antigen as markers in colon carcinoma.',
#  'plasma clearance of carcinoembryonic antigen following hepatic metastatectomy.',
#  'double-blind crossover study of the antiemetic efficacy of high-dose dexamethasone versus high-dose metoclopramide.',
#  'measuring the quality of life of cancer patients: the functional living index-cancer: development and validation.',
#  'methodologic issues in trials of antiemetics.',
#  'illusion and reality: practical pitfalls in interpreting clinical trials.',
#  'pharmacologic rationale for regional drug delivery.',
#  'the biology and treatment of superficial bladder cancer.',
#  'two long-range clinical data bases are terminated: bang, whimper, or ripple?',
#  'parental nutrition: is it oncologically logical?',
#  'parenteral nutrition: is it oncologically logical? a response.',
#  'high-dose cytosine arabinoside and m-amsa is effective therapy in relapsed acute nonlymphocytic leukemia.',
#  'abnormalities of chromosome 16 in association with acute myelomonocytic leukemia and dysplastic bone marrow eosinophils.',
#  'efficacy trial of pipobroman in polycythemia vera and incidence of acute leukemia.',
#  'bone marrow infiltration patterns and their prognostic significance in chronic lymphocytic leukemia: correlations with clinical, immunologic, phenotypic, and cytogenetic data.',
#  "recovery of spermatogenesis after treatment for hodgkin's disease: limiting dose of mopp chemotherapy.",
#  'inefficacy of dacarbazine, mitomycin c, and hepatic irradiation in patients with metastatic adenocarcinoma of the gastrointestinal tract.',
#  'neocarzinostatin versus m-amsa or doxorubicin in hepatocellular carcinoma.',
#  'combined modality treatment of extensive small cell lung cancer: a southwest oncology group study.',
#  'sequential methotrexate and 5-fluorouracil: improved response rate in metastatic colorectal cancer.',
#  'hepatic artery pump infusion: toxicity and results in patients with metastatic colorectal carcinoma.',
#  'preliminary results of a randomized trial of adjuvant doxorubicin for sarcomas: lack of apparent difference between treatment groups.',
#  'treatment of advanced neuroblastoma with supralethal chemotherapy, radiation, and allogeneic or autologous marrow reconstitution.',
#  'neoadjuvant chemotherapy for osteogenic sarcoma: results of a cooperative german/austrian study.',
#  'the clinical significance of radiographically detected pulmonary neoplastic lesions in patients with head and neck cancer.',
#  'intrapericardial tetracycline sclerosis in the treatment of malignant pericardial effusion: an analysis of thirty-three cases.',
#  'accuracy of computerized tomography in determining hepatic tumor size in patients receiving liver transplantation or resection.',
#  'randomized trial of cyclophosphamide, doxorubicin, and 5-fluorouracil alone or alternating with a "cycle active" non-cross-resistant combination in women with visceral metastatic breast cancer: a southeastern cancer study group project.',
#  'relationship between sex hormone binding globulin and estrogen receptors in breast cancer.',
#  'the effect of prior cisplatin therapy on the pharmacokinetics of high-dose methotrexate.',
#  'intraperitoneal cytosine arabinoside therapy in ovarian carcinoma.',
#  'an approach to conducting epidemiologic research within cooperative clinical trials groups.',
#  'charts for the early stopping of pilot studies.',
#  'the effectiveness of behavioral intervention for reduction of nausea and vomiting in children and adolescents receiving chemotherapy.',
#  'lorazepam: a randomized, double-blind, crossover study of a new antiemetic in patients receiving cytotoxic chemotherapy and prochlorperazine.',
#  'a randomized trial of metoclopramide and a combination of dexamethasone and lorazepam for prevention of chemotherapy-induced vomiting.',
#  'macrobiotic diets for cancer treatment and prevention.',
#  'drug concentration errors related to sampling from silastic catheters',
#  'the treatment of neuroblastoma.',
#  "neuroblastoma: the joint center for radiation therapy/dana-farber cancer institute/children's hospital experience.",
#  'diagnosis and significance of liver metastases in small cell carcinoma of the lung.',
#  'advanced neuroblastoma: improved response rate using a multiagent regimen (opec) including sequential cisplatin and vm-26.',
#  "the effects of prior radiation therapy and age on the frequency and duration of complete remission among various four-drug treatments for advanced hodgkin's disease.",
#  'combination therapy with methotrexate and 5-fluorouracil: a prospective randomized clinical trial of order of administration.',
#  "second malignant neoplasms complicating hodgkin's disease: the national cancer institute experience.",
#  'the relevance of internal mammary lymphoscintigraphy in the management of breast carcinoma.',
#  'comparison of the antiemetic effect of high-dose intravenous metoclopramide and high-dose intravenous haloperidol in a randomized double-blind crossover study.',
#  'peripheral t-cell lymphoma: a clinicopathologic study of 42 cases.',
#  'improved prognosis for infants with stage iv neuroblastoma.',
#  'combined therapy for stage iii-iv head and neck cancer: preliminary results.',
#  'follicular large cell lymphoma: analysis and prognostic factors in 62 patients.',
#  'the treatment of extragonadal seminoma.',
#  "prognostic value of blood glucose in hodgkin's disease.",
#  'a phase i-ii trial of cisplatin and dichloromethotrexate in squamous cell cancer of the head and neck.',
#  'a randomized trial of melphalan and prednisone versus melphalan, prednisone, cyclophosphamide, meccnu, and vincristine in untreated multiple myeloma.',
#  'the role of radiation therapy in the management of stage iii follicular lymphomas.',
#  "informed consent for investigational chemotherapy: patients' and physicians' perceptions.",
#  'lymphocyte surface markers in orbital lymphoid neoplasms.',
#  'full dose versus attenuated dose daunorubicin, cytosine arabinoside, and 6-thioguanine in the treatment of acute nonlymphocytic leukemia in the elderly.',
#  'clinical utility of terminal deoxynucleotidyl transferase and adenosine deaminase determinations in adult leukemia with a lymphoid phenotype.',
#  'therapy of chronic lymphocytic leukemia and cutaneous t-cell lymphoma with t101 monoclonal antibody.',
#  "a randomized study comparing chemotherapy alone with chemotherapy followed by radiotherapy in patients with pathologically staged iiia hodgkin's disease.",
#  'long-term remission durability and functional status of patients treated for diffuse histiocytic lymphoma with the chop regimen.',
#  'male breast cancer: a 13-year review of 89 patients.',
#  'electron microscopy in small cell lung carcinomas: clinical correlation.',
#  'influence of place of treatment on diagnosis, treatment, and survival in three pediatric solid tumors.',
#  'isolated testicular relapse in acute lymphocytic leukemia of childhood: categories and influence on survival.',
#  'paradoxical effects of prophylactic phenothiazine antiemetics in children receiving chemotherapy.',
#  'lymphokine-activated human blood monocytes destroy tumor cells but not normal cells under cocultivation conditions.',
#  'dexamethasone-induced increase in in vitro clonogenicity of human neoplasms.',
#  'disclosure of information to adult cancer patients: issues and update.',
#  'recurrent and metastatic mesoblastic nephroma in infancy.',
#  'a reassessment of the clinical implications of the superior vena caval syndrome.',
#  'only by products from many adjuvant breast cancer studies',
#  'high-dose polychemotherapy with autologous bone marrow transplantation in children with relapsed lymphomas.',
#  'a follow-up of a randomized study comparing two chemotherapy treatments for advanced diffuse histiocytic lymphoma.',
#  'lentigo maligna melanoma has no better prognosis than other types of melanoma.',
#  'phase ii study of low-dose recombinant leukocyte a interferon in disseminated malignant melanoma.',
#  'a randomized comparison of high-dose infusion methotrexate versus standard-dose weekly therapy in head and neck squamous cancer.',
#  'a phase ii study of recombinant alpha interferon in patients with recurrent or metastatic breast cancer.',
#  'a comparison of computed tomography and radionuclide scanning for detection of brain metastases in small cell lung cancer.',
#  'pathologic findings at orchiectomy following chemotherapy for disseminated testicular cancer.',
#  "toxic deaths in the second national wilms' tumor study.",
#  "phase i trial of esorubicin (4'deoxydoxorubicin).",
#  'influence of measurement error on assessment of response to anticancer chemotherapy: proposal for new criteria of tumor response.',
#  'data recycling and misreading: two potential errors in pooled data from small studies.',
#  'a proposal for the addition of hyperthermia to treatment regimens for acute and chronic leukemia.',
#  'combination metoclopramide and dexamethasone: an effective antiemetic regimen in outpatients receiving non-cisplatin chemotherapy.',
#  'acivicin: a new glutamine antagonist in clinical trials.',
#  'effects of early leucovorin rescue.',
#  'therapy-related leukemia: a necessary complication of successful systemic chemotherapy?',
#  'leukemia following treatment of germ cell tumors in men.',
#  'outcome following late marrow relapse in childhood acute lymphoblastic leukemia.',
#  'continuous infusion high-dose cytosine arabinoside in refractory childhood leukemia.',
#  "abdominal relapses in irradiated second national wilms' tumor study patients.",
#  'correlations between estrogen receptor, progesterone receptor, and patient characteristics in human breast cancer.',
#  'analysis of serum free light chains by crossed immunoelectrophoresis: comparison with urinary light chains in light chain disease.',
#  "treatment of epidemic kaposi's sarcoma with etoposide or a combination of doxorubicin, bleomycin, and vinblastine.",
#  'cytogenetic studies in 77 patients with chronic lymphocytic leukemia: correlations with clinical, immunologic, and phenotypic data.',
#  'clinical trial of sequential n-phosphonacetyl-l-aspartate, thymidine, and 5-fluorouracil in advanced colorectal carcinoma.',
#  'radiation therapy in the treatment of meningioma: the joint center for radiation therapy experience 1970 to 1982.',
#  'continuous intravenous infusions of bromodeoxyuridine as a clinical radiosensitizer.',
#  'prospective evaluation of changes in computed cranial tomography in patients with small cell lung carcinoma treated with chemotherapy and prophylactic cranial irradiation.',
#  'nutritional parameters affecting erythrocyte polyamine levels in cancer patients.',
#  'tumor-associated peripheral eosinophilia: two unusual cases.',
#  'clinical characteristics associated with the development of anticipatory nausea and vomiting in cancer patients undergoing chemotherapy treatment.',
#  'the dangers of ad hoc protocols.',
#  'the dangers of ad hoc protocols.',
#  'small-cell lung cancer is still a problem.',
#  'chemotherapy of small-cell carcinoma of lung: a randomized comparison of alternating and sequential combination chemotherapy programs.',
#  'randomized trial of radiotherapy to the thorax in limited small-cell carcinoma of the lung treated with multiagent chemotherapy and elective brain irradiation: a preliminary report.',
#  'the effect of specific and nonspecific immunotherapy on natural killer cell activity in patients with non-small-cell lung cancer.',
#  "in vitro sensitivity of myeloblast clonogenic cells to doxorubicin, aclacinomycin a, and 4'-o-tetrapyranyl-doxorubicin: correlations with clinical responses.",
#  'relation of in vitro colony survival to clinical response in a prospective trial of single-agent chemotherapy for metastatic melanoma.',
#  'malignant melanoma in childhood: clinical course and response to chemotherapy.',
#  'monoclonal antibody therapy of malignant melanoma: in vivo localization in cutaneous metastasis after intravenous administration.',
#  '5-fluorouracil, mitomycin, and doxorubicin (fam) in carcinoma of the biliary tract.',
#  'combined 5-fluorouracil and radiation therapy as a surgical adjuvant for poor prognosis gastric carcinoma.',
#  'streptozocin plus fluorouracil versus doxorubicin therapy for metastatic carcinoid tumor.',
#  'a phase iii clinical trial comparing the combination cyclophosphamide, adriamycin, cisplatin with cyclophosphamide, 5-fluorouracil, prednisone in patients with advanced breast cancer.',
#  'pulmonary uptake of technetium 99m macroaggregated albumin: a predictor of gastrointestinal toxicity during hepatic artery perfusion.',
#  'sudden death in cancer patients receiving lithium.',
#  'totally implantable system for peritoneal access.',
#  'the importance of dose intensity in chemotherapy of metastatic breast cancer.',
#  'continuous infusion chemotherapy: a critical review.',
#  'multiple primary malignancies.',
#  'spontaneous mutation to chemotherapy resistance: implications of the goldie-coldman model for the management of ovarian cancer.',
#  'alternating combination chemotherapy for stages iii and iv ovarian carcinoma.',
#  'combination intraperitoneal chemotherapy with cisplatin, cytarabine, and doxorubicin for refractory ovarian carcinoma and other malignancies principally confined to the peritoneal cavity.',
#  'effects of different forms of central nervous system prophylaxis on neuropsychologic function in childhood leukemia.',
#  'comparison of 5-fluorouracil with ftorafur in adjuvant chemotherapies with combined inductive and maintenance therapies for gastric cancer.',
#  'vp-16-213 in combination chemotherapy with chest irradiation for small-cell lung cancer: a randomized trial of the piedmont oncology association.',
#  'sites of recurrence in resected stage i non-small-cell lung cancer: a guide for future studies.',
#  'the role of computed tomography of the chest in the management of small-cell lung cancer.',
#  "hairy-cell leukemia: induction of complete remission with pentostatin (2'-deoxycoformycin).",
#  'an eastern cooperative oncology group evaluation of combinations of methyl-ccnu, mitomycin c, adriamycin, and 5-fluorouracil in advanced measurable gastric cancer (est 2277).',
#  'hepatic artery ligation and portal vein infusion for liver metastases from colon cancer.',
#  'randomized study of systemic chemotherapy following complete excision of nonosseous sarcomas.',
#  'brain metastases and testicular tumors: need for aggressive therapy.',
#  'cyclophosphamide, methotrexate, and 5-fluorouracil chemotherapy in women more than 65 years old with advanced breast cancer: the elimination of age trends in toxicity by using doses based on creatinine clearance.',
#  'outcomes and complications of continuous intraspinal narcotic analgesia for cancer pain control.',
#  "is it an e lesion or stage iv? an unsettled issue in hodgkin's disease staging.",
#  'acute leukemia in two patients treated with high-dose melphalan and autologous marrow transplantation for malignant solid tumors.',
#  "report of children's cancer study group.",
#  'correlation of chromosome abnormalities with patient characteristics, histologic subtype, and induction success in children with acute nonlymphocytic leukemia.',
#  'abnormal computed tomography brain scans in children with acute lymphoblastic leukemia: serial long-term follow-up.',
#  'stage iv diffuse large-cell lymphoma: a long-term analysis.',
#  'cerebrospinal fluid vasopressin as a marker of central nervous system metastases from small-cell bronchogenic carcinoma.',
#  'etoposide (vp-16) and cisplatin: an effective treatment for relapse in small-cell lung cancer.',
#  'long-term survival in small-cell carcinoma of the lung: a population experience.',
#  'the human tumor clonogenic assay in human breast cancer.',
#  'a controlled trial of the effect of 4-hydroxypyrazolopyrimidine (allopurinol) on the toxicity of a single bolus dose of 5-fluorouracil.',
#  'phase i trial of misonidazole (nsc#261037) plus cyclophosphamide in solid tumors.',
#  'altered central nervous system pharmacology of methotrexate in childhood leukemia: another sign of meningeal relapse.',
#  'biliary sclerosis in patients receiving hepatic arterial infusions of floxuridine.',
#  'secondary malignancies of the penis and epididymis: a case report and review of the literature.',
#  "synchronous neuroblastoma and von recklinghausen's disease: a review of the literature.",
#  "prognostic value of blood glucose in hodgkin's disease.",
#  "prognostic value of blood glucose in hodgkin's disease.",
#  'morphological subclassification of follicular lymphoma: variability of diagnoses among hematopathologists, a collaborative study between the repository center and pathology panel for lymphoma clinical studies.',
#  'co-trimoxazole prophylaxis during high-dose chemotherapy of small-cell lung cancer.',
#  'chemotherapy for metastatic non-small-cell bronchogenic carcinoma: est 2575, generation v--a randomized comparison of four cisplatin-containing regimens.',
#  'chronic myelogenous leukemia: is aggressive treatment indicated?',
#  'extensive-stage small-cell bronchogenic carcinoma: intensive induction chemotherapy with high-dose cyclophosphamide plus high-dose etoposide.',
#  'late intensification in small-cell lung cancer: a phase i study of high doses of cyclophosphamide and etoposide with autologous bone marrow transplantation.',
#  'intensive combination chemotherapy (roap 10) and splenectomy in the management of chronic myelogenous leukemia.',
#  'unexpectedly severe toxicity from intensive early treatment of childhood lymphoblastic leukemia.',
#  'methylglyoxal-bis(guanylhydrazone) in hormone-resistant adenocarcinoma of the prostate.',
#  'acute effects of salmon calcitonin in multiple myeloma: a valuable method for serial evaluation of osteoclastic lesions and disease activity--a prospective study of 125 patients.',
#  'high-dose cisplatin with sodium thiosulfate protection.',
#  'analysis of treatment results in craniopharyngioma.',
#  'adjuvant chemotherapy of breast cancer: a promising experiment or standard practice?',
#  'adjuvant cmfp versus cmfp plus tamoxifen versus observation alone in postmenopausal, node-positive breast cancer patients: three-year results of an eastern cooperative oncology group study.',
#  'randomized trial of three combinations of cisplatin with vindesine and/or vp-16-213 in the treatment of advanced non-small-cell lung cancer.',
#  "extended versus involved fields irradiation combined with mopp chemotherapy in early clinical stages of hodgkin's disease.",
#  'high-dose intravenous metoclopramide versus combination high-dose metoclopramide and intravenous dexamethasone in preventing cisplatin-induced nausea and emesis: a single-blind crossover comparison of antiemetic efficacy.',
#  'adjuvant systemic therapy for resectable breast cancer.',
#  'mitomycin: ten years after approval for marketing.',
#  'megestrol acetate therapy for advanced breast cancer.',
#  'tamoxifen flare in advanced endometrial carcinoma.',
#  'therapy for metastatic colorectal cancer with hepatic artery infusion chemotherapy using a subcutaneous implanted pump.',
#  "lung cancer in hodgkin's disease: association with previous radiotherapy.",
#  'changes in criteria for tumor response.',
#  'advanced testicular cancer: treatment choices in the "land of plenty".',
#  'chemotherapy of extragonadal germ cell tumors.',
#  'improved survival with cyclic chemotherapy for nonseminomatous germ cell tumors of the testis.',
#  'vab-6 as initial treatment of patients with advanced seminoma.',
#  'pilot trial of murine monoclonal antibodies in patients with advanced melanoma.',
#  'patterns of recurrence in patients with high-grade soft-tissue sarcomas.',
#  'ifosfamide: an active drug in the treatment of adenocarcinoma of the pancreas.',
#  'obstructive and perforative colonic carcinoma: patterns of failure.',
#  "prognostic groups for management of localized hodgkin's disease.",
#  'a pilot study of protracted venous infusion of 5-fluorouracil and concomitant radiation therapy.',
#  'phase i trial of an implanted battery-powered, programmable drug delivery system for continuous doxorubicin administration.',
#  'the effect of chemotherapeutic agents on chemotaxis and random migration of human leukocytes.',
#  'neoplasia and the erythron.',
#  "karnofsky memorial lecture. the low-grade non-hodgkin's lymphomas: challenges and opportunities.",
#  'treatment of locally unresectable cancer of the stomach and pancreas: a randomized comparison of 5-fluorouracil alone with radiation plus concurrent and maintenance 5-fluorouracil--an eastern cooperative oncology group study.',
#  "cyclophosphamide versus 5-fluorouracil, doxorubicin, and mitomycin c (fam') in the treatment of hormone-resistant metastatic carcinoma of the prostate: a preliminary report of a randomized trial.",
#  'beyond proforma consent for childhood cancer research.',
#  'detection of p-glycoprotein in ovarian cancer: a molecular marker associated with multidrug resistance.',
#  'childhood testicular relapse.',
#  'monoclonal antibody immunocytology: potential applications for staging and monitoring malignant disease activity.',
#  'detection of bone marrow metastasis in small-cell lung cancer by monoclonal antibody.',
#  '13-cis-retinoic acid does not increase the true remission rate and the duration of true remission (induced by cytotoxic chemotherapy) in patients with chronic phase chronic myelogenous leukemia.',
#  'clinical relevance of lymphoblast biological features in children with acute lymphoblastic leukemia.',
#  'remission induction of meningeal leukemia with high-dose intravenous methotrexate.',
#  'primary lymphomas of the central nervous system: patterns of failure and factors that influence survival.',
#  "non-hodgkin's lymphoma of the stomach: a prospective pilot study of surgery plus chemotherapy in early and advanced disease.",
#  "treatment of acquired immunodeficiency syndrome--related kaposi's sarcoma with lymphoblastoid interferon.",
#  "anaplastic wilms' tumor: clinical and pathologic studies.",
#  "prognosis for wilms' tumor patients with nonmetastatic disease at diagnosis--results of the second national wilms' tumor study.",
#  'second malignant neoplasms in children: an update from the late effects study group.',
#  'echocardiographic abnormalities following cardiac radiation.',
#  'neoplastic fever responds to the treatment of an adequate dose of naproxen.',
#  'risk-benefit relationships in cancer clinical trials: the ecog experience in non-small-cell lung cancer.',
#  'comparative activity and toxicity of cis-diamminedichloroplatinum (ddp) and a combination of doxorubicin, cyclophosphamide, and ddp in disseminated transitional cell carcinomas of the urinary tract.',
#  'the effect of administration rate on cisplatin-induced emesis.',
#  'amsacrine (amsa)--a clinical review.',
#  "reduction of fatal complications from combined modality therapy in hodgkin's disease.",
#  'high-dose methotrexate-induced neurotoxicity associated with elevation of csf myelin basic protein.',
#  'how much is too much high-dose cytosine arabinoside?',
#  'homoharringtonine as a new antileukemic agent.',
#  'successful treatment of resistant germinal neoplasms with vp-16 and cisplatin: results of a southeastern cancer study group trial.',
#  'a randomized trial of adjuvant chemotherapy in head and neck cancer.',
#  'cytosine-arabinoside-induced colitis and peritonitis: nonoperative management.',
#  'cerebellar toxicity following high-dose cytosine arabinoside.',
#  'homoharringtonine: an effective new drug for remission induction in refractory nonlymphoblastic leukemia.',
#  'central nervous system morbidity following an initial isolated central nervous system relapse and its subsequent therapy in childhood acute lymphoblastic leukemia.',
#  "curability of burkitt's lymphoma with high-dose cyclophosphamide-high-dose methotrexate therapy and intrathecal chemoprophylaxis.",
#  "the significance of the residual mediastinal mass in treated hodgkin's disease.",
#  'renal involvement in diffuse aggressive lymphomas: results of treatment with combination chemotherapy.',
#  'phase ii study of recombinant alpha-2 interferon in resistant multiple myeloma.',
#  'local-regional failure in patients treated with adjuvant chemotherapy for breast cancer.',
#  'intraocular retinoblastoma group v: an analysis of prognostic factors.',
#  'perioperative blood transfusions are associated with increased rates of recurrence and decreased survival in patients with high-grade soft-tissue sarcomas of the extremities.',
#  'complications and management of implanted venous access catheters.',
#  'immunogenicity of hepatitis b vaccine in oncology patients receiving chemotherapy.',
#  'carcinoma-associated hemolytic-uremic syndrome: a complication of mitomycin c chemotherapy.',
#  'drug-induced antibodies during 2-n-methyl-9-hydroxyellipticinium acetate (nsc-264137) treatment: schedule dependency and relationship to hemolysis.',
#  "superoxide anion (o-2) production by peripheral blood monocytes in hodgkin's disease and malignant lymphoma.",
#  "ewing's sarcoma in bones of the hands and feet: a clinicopathologic study and review of the literature.",
#  'the flip flop pump syndrome.',
#  'cancer prevention.',
#  "pathologic stages ia and iia hodgkin's disease: results of treatment with radiotherapy alone, 1968-1980.",
#  'inhibition of phorbol ester--induced human epidermal ornithine decarboxylase activity by oral compounds: a possible role in human chemoprevention studies.',
#  'etoposide (vp-16) with prednisone and vincristine for the treatment of refractory acute lymphoblastic leukemia.',
#  'a characteristic pattern of leukemic cell differentiation without cytoreduction during remission induction in acute promyelocytic leukemia.',
#  'dna-rna measurements in patients with acute leukemia undergoing remission induction therapy.',
#  'iodine 125 suture implants in the management of advanced tumors in the neck attached to the carotid artery.',
#  'treatment of nasopharyngeal carcinoma with human leukocyte interferon.',
#  'pharmacokinetics of 5-fluorouracil during hyperthermic pelvic isolation-perfusion.',
#  'phase i trial of n-methylformamide (nmf, nsc 3051).',
#  'lorazepam in cancer patients treated with cisplatin: a drug having antiemetic, amnesic, and anxiolytic effects.',
#  'criteria of tumor response used in clinical trials of chemotherapy.',
#  'tumor-associated antigens--an overview.',
#  "pathologic stages ia and iia hodgkin's disease: results of treatment with radiotherapy alone (1968-1980).",
#  'moderate versus aggressive chemotherapy of nodular lymphocytic poorly differentiated lymphoma.',
#  'the importance of an isolated central nervous system relapse in children with acute lymphoblastic leukemia.',
#  'a prospective randomized comparison of epirubicin and doxorubicin in patients with advanced breast cancer.',
#  'a reevaluation of nonhormonal cytotoxic chemotherapy in the treatment of prostatic carcinoma.',
#  'a controlled evaluation of combined 5-fluorouracil, doxorubicin, and mitomycin c (fam) for the treatment of advanced non-small-cell lung cancer.',
#  'fam therapy for advanced gastric cancer: an ideal standard?',
#  'adult t cell leukemia with atypical surface phenotypes: clinical correlation.',
#  'extraskeletal mesenchymal chondrosarcoma: case report and review of the literature.',
#  'population-based study of small-cell lung cancer.',
#  "management of pathologic stage iiia hodgkin's disease.",
#  'leukemia following treatment of germ cell tumors in men.',
#  'dose, response, and survival in metastatic mammary cancer',
#  'dose intensity in chemotherapy',
#  'plasma melatonin and the hormone-dependency of human breast cancer.',
#  'effect of initial resection of small-cell carcinoma of the lung: a review of southwest oncology group study 7628.',
#  'activation of monocyte-mediated tumoricidal activity in patients with acquired immunodeficiency syndrome.',
#  'intraperitoneal chemotherapy with high-dose cisplatin and cytosine arabinoside for refractory ovarian carcinoma and other malignancies principally involving the peritoneal cavity.',
#  'comparison of caf versus cmfp in metastatic breast cancer: analysis of prognostic factors.',
#  'effects of intravenous hyperalimentation during treatment in patients with small-cell lung cancer.',
#  'high-dose cyclophosphamide in small-cell carcinoma of the lung.',
#  'combined modality therapy with radiotherapy, chemotherapy, and immunotherapy in limited small-cell carcinoma of the lung: a phase iii cancer and leukemia group b study.',
#  'high-dose cytosine arabinoside therapy with and without anthracycline antibiotics for remission reinduction of acute nonlymphoblastic leukemia.',
#  'is there evidence that chemotherapy is of benefit to patients with carcinoma of the prostate?',
# ...
#  'ten-year analysis of the nsabp b-50 study.',
#  'progress in inflammatory breast cancer: cause for cautious optimism.',
#  'bench-to-bedside research and the human tumor stem-cell assay--bridging the credibility gap.',
#  "results of treatment of advanced-stage burkitt's lymphoma and b cell (sig+) acute lymphoblastic leukemia with high-dose fractionated cyclophosphamide and coordinated high-dose methotrexate and cytarabine.",
#  'behenoyl cytosine arabinoside, daunorubicin, 6-mercaptopurine, and prednisolone combination therapy for acute myelogenous leukemia in adults and prognostic factors related to remission duration and survival length.',
#  'therapy-related leukemia and myelodysplastic syndrome: clinical, cytogenetic, and prognostic features.',
#  'medical research council leukaemia trial--ukall v: an attempt to reduce the immunosuppressive effects of therapy in childhood acute lymphoblastic leukemia. report to the council by the working party on leukaemia in childhood.',
#  'primary chemotherapy in the treatment of inflammatory breast carcinoma: a study of 230 cases from the institut gustave-roussy.',
#  'a new endpoint for the assessment of adjuvant therapy in postmenopausal women with operable breast cancer.',
#  'a randomized study comparing a high and a standard dose of cisplatin in combination with etoposide in the treatment of advanced non-small-cell lung carcinoma.',
#  'high-dose cisplatin in hypertonic saline: reduced toxicity of a modified dose schedule and correlation with plasma pharmacokinetics. a northern california oncology group pilot study in non-small-cell lung cancer.',
#  'an eortc gastrointestinal group evaluation of the combination of sequential methotrexate and 5-fluorouracil, combined with adriamycin in advanced measurable gastric cancer.',
#  'high-dose busulfan and cyclophosphamide with autologous bone marrow transplantation support in advanced malignancies in children: a phase ii study.',
#  'high-dose chemotherapy without autologous bone marrow transplantation in melanoma.',
#  'regional isolated limb perfusion of melanoma intransit metastases using mechlorethamine (nitrogen mustard).',
#  'use of in vitro dose response effects to select antineoplastics for high-dose or regional administration regimens.',
#  'phase i and pharmacologic study of hexamethylene bisacetamide in patients with advanced cancer.',
#  'transient cerebral dysfunction secondary to high-dose methotrexate.',
#  'surgical treatment of spinal cord compression in kidney cancer.',
#  'a critical appraisal of low-dose cytosine arabinoside in patients with acute non-lymphocytic leukemia and myelodysplastic syndromes.',
#  'acute toxicity of epirubicin.',
#  'high-dose cytosine arabinoside with amsacrine for treatment of acute lymphoblastic leukemia.',
#  'why has so much chemotherapy done so little in head and neck cancer?',
#  'adjuvant chemotherapy of osteosarcoma: no runs, no hits, two men left on base.',
#  'abvd versus mopp: which is better?',
#  'clinical staging in rhabdomyosarcoma: current limitations and future prospects.',
#  'an analysis of induction and adjuvant chemotherapy in the multidisciplinary treatment of squamous-cell carcinoma of the head and neck.',
#  'adjuvant chemotherapy for osteosarcoma: a randomized prospective trial.',
#  "long-term results of combined chemotherapy-radiotherapy approach in hodgkin's disease: superiority of abvd plus radiotherapy versus mopp plus radiotherapy.",
#  "radiation therapy salvage of hodgkin's disease following chemotherapy failure.",
#  'prognostic significance of staging factors of the uicc staging system in childhood rhabdomyosarcoma: a report from the intergroup rhabdomyosarcoma study (irs-ii).',
#  'survival from first recurrence: relative importance of prognostic factors in 1,015 breast cancer patients.',
#  'screening for recurrent breast cancer--its effectiveness and prognostic value.',
#  'factors influencing options in primary breast cancer treatment.',
#  'high-dose cytosine arabinoside as the initial treatment of poor-risk patients with acute nonlymphocytic leukemia: a leukemia intergroup study.',
#  'phase ii clinical trial of triazinate in combination with mitomycin c for patients with advanced gastric cancer.',
#  'randomized comparison of cyclophosphamide, imidazole carboxamide, and adriamycin versus cyclophosphamide and adriamycin in patients with advanced stage malignant mesothelioma: a sarcoma intergroup study.',
#  'a phase i study of menogaril in patients with advanced cancer.',
#  'malignant melanoma in the elderly.',
#  'the impact of palliative irradiation on the management of patients with acquired immune deficiency syndrome.',
#  'a randomized study of oral nutritional support versus ad lib nutritional intake during chemotherapy for advanced colorectal and non-small-cell lung cancer.',
#  'superficial bladder cancer: the primacy of grade in the development of invasive disease.',
#  'a new technique for placement of tunneled subclavian right atrial catheters: experience with 130 cases.',
#  'a totally implanted venous access system used in pediatric patients with cancer.',
#  'antiemetic activity of high doses of metoclopramide combined with methylprednisolone versus metoclopramide alone in cisplatin-treated cancer patients: a randomized double-blind trial of the italian oncology group for clinical research.',
#  'suppressor cell function in solid tumor cancer patients.',
#  'early results of the monoclonal antibody ovtl3 in specific detection of ovarian cancer.',
#  'analysis of dose intensity for adjuvant chemotherapy trials in stage ii breast cancer.',
#  'gonadal dysfunction in patients treated for metastatic germ-cell tumors',
#  'high-dose chemotherapy for breast cancer.',
#  'whither carboplatin?--a replacement for or an alternative to cisplatin?',
#  'a phase i-ii study of intensive-dose adriamycin for advanced breast cancer.',
#  'high-dose induction chemotherapy of metastatic breast cancer in protected environment: a prospective randomized study.',
#  'carboplatin (paraplatin; jm8) and etoposide (vp-16) as first-line combination therapy for small-cell lung cancer.',
#  'a phase i-ii trial of carboplatin and 5-fluorouracil combination chemotherapy in advanced carcinoma of the head and neck.',
#  'high-dose carboplatin in refractory ovarian cancer patients.',
#  'differences in cerebrospinal fluid penetration of corticosteroids: possible relationship to the prevention of meningeal leukemia.',
#  'cytologic transformation in cutaneous t cell lymphoma: a clinicopathologic entity associated with poor prognosis.',
#  'malignant lymphoma: cardiac involvement at initial presentation.',
#  'the detection of bone marrow involvement by lymphoma using magnetic resonance imaging.',
#  "retroperitoneal fibrosis following treatment for hodgkin's disease.",
#  "semen cryopreservation and artificial insemination for hodgkin's disease.",
#  "the effect of mediastinal irradiation on cardiac function of patients treated during childhood and adolescence for hodgkin's disease.",
#  'metastatic patterns in small-cell lung cancer: correlation of autopsy findings with clinical parameters in 537 patients.',
#  'detection of liver metastases in small-cell lung cancer: a comparison of peritoneoscopy with liver biopsy and ultrasonography with fine-needle aspiration.',
#  'a phase i-ii study of bialkylator chemotherapy, high-dose thiotepa, and cyclophosphamide with autologous bone marrow reinfusion in patients with advanced cancer.',
#  'high-dose chemoradiotherapy with bone marrow transplantation as consolidation treatment in neuroblastoma: an unselected group of stage iv patients over 1 year of age.',
#  '5-fluorouracil and folinic acid in the treatment of metastatic colorectal cancer: a randomized comparison. a southwest oncology group study.',
#  'adjuvant methotrexate escalated to toxicity for resectable stage iii and iv squamous head and neck carcinomas--a prospective, randomized study.',
#  'recombinant alfa interferon in renal cell carcinoma: a randomized trial of two routes of administration.',
#  'gallium nitrate inhibits accelerated bone turnover in patients with bone metastases.',
#  'ocular relapse in the anterior chamber in childhood acute lymphoblastic leukemia.',
#  'creatinine clearance as a predictor of ultrafilterable platinum disposition in cancer patients treated with cisplatin: relationship between peak ultrafilterable platinum plasma levels and nephrotoxicity.',
#  'treatment of hepatosplenic candidiasis with liposomal-amphotericin b.',
#  'cisplatin-induced hepatic toxicity.',
#  'psychotoxicity from antineoplastic agents.',
#  'mopp after two decades.',
#  'soft-tissue sarcomas of the extremities.',
#  'progression sites of metastatic breast cancer under chemotherapy.',
#  'hormone stimulation and chemotherapy for breast cancer.',
#  'stress factors and breast cancer outcome.',
#  'coping with ineffective therapies.',
#  'the other chop.',
#  'conventional versus cytokinetic polychemotherapy with estrogenic recruitment in metastatic breast cancer: results of a randomized cooperative trial.',
#  'correlation of stress factors with sustained depression of natural killer cell activity and predicted prognosis in patients with breast cancer.',
#  'evaluation of high-dose versus standard fac chemotherapy for advanced breast cancer in protected environment units: a prospective randomized study.',
#  'nonoperative therapy for squamous-cell cancer of the esophagus.',
#  'a new regimen of amsacrine with high-dose cytarabine is safe and effective therapy for acute leukemia.',
#  'successful reinduction of patients with acute lymphoblastic leukemia who relapse following bone marrow transplantation.',
#  'acute lymphoblastic leukemia with chromosomal 5;14 translocation and hypereosinophilia: case report and literature review.',
#  'a clinical and pharmacokinetic study of mitoxantrone in acute nonlymphocytic leukemia.',
#  'prognosis in chronic lymphocytic leukemia: a retrospective multicentric study from the gimema group.',
#  'results of mime salvage regimen for recurrent or refractory lymphoma.',
#  'effect of the degree of nodularity on the survival of patients with nodular lymphomas.',
#  "sequential hydroxyurea-cytarabine chemotherapy for refractory non-hodgkin's lymphoma.",
#  'prevention of graft-versus-host disease in hla-matched bone marrow transplantation for malignant diseases: a multicentric study of 62 patients using 3-pan-t monoclonal antibodies and rabbit complement.',
#  'alternating cycles of etoposide plus cisplatin and vab-6 in the treatment of poor-risk patients with germ cell tumors.',
#  'a prospective randomized trial of maintenance versus nonmaintenance intravesical bacillus calmette-guérin therapy of superficial bladder cancer.',
#  'high-dose intensity systemic therapy of metastatic bladder cancer.',
#  'adjuvant chemotherapy for high-risk squamous-cell carcinoma of the head and neck.',
#  'carboplatin and recurrent childhood brain tumors.',
#  'phase ii diaziquone-based chemotherapy trials in patients with anaplastic supratentorial astrocytic neoplasms.',
#  'evaluation of three biochemical markers for serially monitoring the therapy of small-cell lung cancer.',
#  'wound complications in the multimodality treatment of extremity and superficial truncal sarcomas.',
#  'effect of calcium channel blockers on human cfu-gm with cytotoxic drugs.',
#  'reduction of toxicity of interleukin-2 and lymphokine-activated killer cells in humans by the administration of corticosteroids.',
#  'effects of patient management guidelines on physician practice patterns: the community hospital oncology program experience.',
#  'ifosfamide neurotoxicity in children.',
#  'prognostic factors in metastatic carcinoma of unknown primary.',
#  'early recognition of the effects of publication bias',
#  'arabinosyl cytosine: a 20-year update.',
#  "salvage treatment for hodgkin's disease in relapse.",
#  'will monoclonal antibodies find a place in our therapeutic armamentarium?',
#  'multimodality therapy of esophageal carcinoma: still an experimental approach.',
#  'high-dose cytosine arabinoside in the treatment of acute myelogenous leukemia: contributions to outcome of clinical and laboratory attributes.',
#  "wide-field radiation therapy alone or with chemotherapy for hodgkin's disease in relapse from combination chemotherapy.",
#  "radiotherapy with curative intent: an option in selected patients relapsing after chemotherapy for advanced hodgkin's disease.",
#  "mime chemotherapy (methyl-gag, ifosfamide, methotrexate, etoposide) as treatment for recurrent hodgkin's disease.",
#  'radioimmunodetection and radioimmunotherapy of cutaneous t cell lymphomas using an 131i-labeled monoclonal antibody: an illinois cancer council study.',
#  'wr-2721 and high-dose cisplatin: an active combination in the treatment of metastatic melanoma.',
#  'the role of misonidazole combined with intraoperative radiation therapy in the treatment of pancreatic carcinoma.',
#  'the superiority of combination chemotherapy including etoposide based on in vivo cell cycle analysis in the treatment of extensive small-cell lung cancer: a randomized trial of 288 consecutive patients.',
#  'multimodal therapy for limited small-cell lung cancer: a randomized study of induction combination chemotherapy with or without thoracic radiation in complete responders; and with wide-field versus reduced-field radiation in partial responders: a southwest oncology group study.',
#  'localized extremity soft tissue sarcoma: an analysis of factors affecting survival.',
#  'eastern cooperative oncology group: a comparison of adjuvant doxorubicin and observation for patients with localized soft tissue sarcoma.',
#  'cisplatin therapy for disseminated mixed mesodermal sarcoma of the uterus.',
#  'combined therapies for squamous-cell carcinoma of the esophagus, a southwest oncology group study (swog-8037).',
#  'sequential chemotherapy and radiation for nasopharyngeal cancer: absence of long-term benefit despite a high rate of tumor response to chemotherapy.',
#  'hepatic arterial infusion of mitoxantrone in the treatment of primary hepatocellular carcinoma.',
#  'verapamil and adriamycin in the treatment of drug-resistant ovarian cancer patients.',
#  'subcutaneous infusion of bleomycin--a practical alternative to intravenous infusion.',
#  'gonadal function after surgery and chemotherapy in men with stage ii and iii nonseminomatous testicular tumors.',
#  'hypoxanthine:guanine phosphoribosyltransferase activity in primary human osteosarcomas. a rationale for therapy with methotrexate-thymidine rescue?',
#  'breast cancers negative for estrogen receptor but positive for progesterone receptor, a true entity?',
#  'herniated lumbar disc disease in patients with malignancy.',
#  'local infusion of urokinase for the lysis of thrombosis associated with permanent central venous catheters in cancer patients.',
#  'treatment-related toxicity in elderly patients with malignant lymphoma.',
#  'doxorubicin combination chemotherapy in ovarian carcinoma.',
#  'cerebral dysfunction secondary to high-dose methotrexate.',
#  'a ten-year update of chop-bleo in the treatment of diffuse large-cell lymphoma.',
#  'operation for small-cell carcinoma revisited.',
#  'treatment strategies for "high-risk" leukemia.',
#  'molecular monitoring of pre-b acute lymphocytic leukemia.',
#  'time-dose factors in chemotherapy: expanding the concept of dose-intensity.',
#  'the role of surgery in the management of selected patients with small-cell carcinoma of the lung.',
#  'high-dose induction chemotherapy with cyclophosphamide, etoposide, and cisplatin for extensive-stage small-cell lung cancer.',
#  'a strategy for evaluation of new treatments in untreated patients: application to a clinical trial of amsa for acute leukemia.',
#  'intensive remission consolidation therapy in the treatment of acute nonlymphocytic leukemia.',
#  "marrow transplantation for acute nonlymphocytic leukemia following therapy for hodgkin's disease.",
#  'gene rearrangements as markers of clonal variation and minimal residual disease in acute lymphoblastic leukemia.',
#  ...]
